# %% [markdown]
# ## Import and install dependencies

# %%
# !pip install causal-conv1d>=1.2.0
# !pip install mamba-ssm
# Out:
# Collecting mamba-ssm
#   Downloading mamba_ssm-1.2.0.post1.tar.gz (34 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (from mamba-ssm) (2.1.2)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from mamba-ssm) (21.3)
# Requirement already satisfied: ninja in /opt/conda/lib/python3.10/site-packages (from mamba-ssm) (1.11.1.1)
# Collecting einops (from mamba-ssm)
#   Downloading einops-0.8.0-py3-none-any.whl.metadata (12 kB)
# Collecting triton (from mamba-ssm)
#   Downloading triton-2.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.4 kB)
# Requirement already satisfied: transformers in /opt/conda/lib/python3.10/site-packages (from mamba-ssm) (4.39.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->mamba-ssm) (3.1.1)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch->mamba-ssm) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch->mamba-ssm) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch->mamba-ssm) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch->mamba-ssm) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch->mamba-ssm) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch->mamba-ssm) (2024.2.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /opt/conda/lib/python3.10/site-packages (from transformers->mamba-ssm) (0.22.2)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from transformers->mamba-ssm) (1.26.4)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from transformers->mamba-ssm) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers->mamba-ssm) (2023.12.25)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from transformers->mamba-ssm) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /opt/conda/lib/python3.10/site-packages (from transformers->mamba-ssm) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from transformers->mamba-ssm) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.10/site-packages (from transformers->mamba-ssm) (4.66.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch->mamba-ssm) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->transformers->mamba-ssm) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->transformers->mamba-ssm) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->transformers->mamba-ssm) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->transformers->mamba-ssm) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch->mamba-ssm) (1.3.0)
# Downloading einops-0.8.0-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 1.9 MB/s eta 0:00:00
# Downloading triton-2.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (168.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.1/168.1 MB 8.9 MB/s eta 0:00:00:00:0100:01
# Building wheels for collected packages: mamba-ssm
#   Building wheel for mamba-ssm (setup.py) ... done
#   Created wheel for mamba-ssm: filename=mamba_ssm-1.2.0.post1-cp310-cp310-linux_x86_64.whl size=137581036 sha256=37a78248a6b0c9157d6408484d93dd1f9a9cc43cebcbd160c9312fb8bb690bac
#   Stored in directory: /root/.cache/pip/wheels/22/6e/60/ddd5c574b5793a30028f2cabdacd2a3ec2276edaaa8c00fd35
# Successfully built mamba-ssm
# Installing collected packages: triton, einops, mamba-ssm
# Successfully installed einops-0.8.0 mamba-ssm-1.2.0.post1 triton-2.3.0

# %%
import json
import numpy as np
import random
import torch
import time
import pandas as pd
import gc

# %% [markdown]
# Making the notebook deterministic

# %%
def fix_random(seed: int) -> None:
    np.random.seed(seed)
    random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)

    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True


fix_random(seed=42)

# %%
data_path = "/kaggle/input/squad0"

# %% [markdown]
# This function loads a little SQuAD dataset for evaluation.

# %%
def load(path):
    data = []
    with open(f"{data_path}/squad_val_1k.jsonl", "r") as file:
          for line in file:
              try:
                  data.append(json.loads(line))
              except Exception as e:
                  print("json processing exception", e)
                  continue
    return data

# %%
data = load('squad_val_1k.jsonl')
print(data[0])
# Out:
# {'context': 'The Panthers beat the Seattle Seahawks in the divisional round, running up a 31–0 halftime lead and then holding off a furious second half comeback attempt to win 31–24, avenging their elimination from a year earlier. The Panthers then blew out the Arizona Cardinals in the NFC Championship Game, 49–15, racking up 487 yards and forcing seven turnovers.', 'prompt': 'How many yards did the Panthers get for the division championshipt game?', 'response': '487'}

# %% [markdown]
# This functions necessary for evaluating the models. More description below.

# %%
#This function generate the prompt. If we set the few_shot parameter to True, then it will generate
#a prompt, which uses few-shot prompting technique, otherwise not.
def generate_prompt(few_shot, question_with_context):
    questions = []
    if few_shot:
        three_shot_prompting = [
        {
            "context" : "In 1993, the FCC repealed the Financial Interest and Syndication Rules, once again allowing networks to hold interests in television production studios. That same year, Capital Cities/ABC purchased the French animation studio DIC Entertainment; it also signed an agreement with Time Warner Cable to carry its owned-and-operated television stations on the provider's systems in ABC O&O markets. By that year, ABC had a total viewership share of 23.63% of American households, just below the limit of 25% imposed by the FCC.",
            "question": "What French animation studio did ABC purchase in 1993?",
            "answer": "DIC Entertainment",
        },
        {
            "context" : "On April 12, 1961, Soviet cosmonaut Yuri Gagarin became the first person to fly in space, reinforcing American fears about being left behind in a technological competition with the Soviet Union. At a meeting of the US House Committee on Science and Astronautics one day after Gagarin's flight, many congressmen pledged their support for a crash program aimed at ensuring that America would catch up. Kennedy was circumspect in his response to the news, refusing to make a commitment on America's response to the Soviets.",
            "question": "How many days after Gagarin's flight did the US House Committee on Science and Astronautics meet?",
            "answer": "one day",
        },
        {
            "context" : "The customary law of Normandy was developed between the 10th and 13th centuries and survives today through the legal systems of Jersey and Guernsey in the Channel Islands. Norman customary law was transcribed in two customaries in Latin by two judges for use by them and their colleagues: These are the Très ancien coutumier (Very ancient customary), authored between 1200 and 1245; and the Grand coutumier de Normandie (Great customary of Normandy, originally Summa de legibus Normanniae in curia laïcali), authored between 1235 and 1245.",
            "question": "Where are Jersey and Guernsey?",
            "answer": "Channel Islands",
        }
        ]
        for item in question_with_context:
            prompt = f"You are a question answering bot. Your task is to answer the questions based on the appropriate contexts and your own knowledge. Your answers should contain only the most important things and should be as short as possible."
            prompt = f"{prompt}\n\n" + "\n\n".join([f"{p['context']}\n\nQ: {p['question']}\n\nA: {p['answer']}" for p in three_shot_prompting])
            prompt = f"{prompt}\n\n{item}\n\nA:"
            questions.append(prompt)
    else:
        for item in question_with_context:
            prompt = f"You are a question answering bot. Your task is to answer the questions based on the appropriate contexts and your own knowledge. Your answers should contain only the most important things and should be as short as possible."
            prompt = f"{prompt}\n\n{item}\n\nA:"
            questions.append(prompt)
    return questions

#This function generate the text for the prompt.
def run_with_SQuAD(model, tokenizer, question, few_shot):
    prompt = generate_prompt(few_shot, question)
    
    inputs = tokenizer(prompt, padding=True, truncation=True, return_tensors="pt")
    input_ids = inputs["input_ids"].cuda()
    attention_mask = inputs["attention_mask"].cuda()
    model.cuda()

    out = model.generate(
        input_ids=input_ids,
        max_length=input_ids.shape[1] + 128,
        eos_token_id=tokenizer.eos_token_id,
        attention_mask=attention_mask
    )
    
    answers = []
    num_tokens = []
    
    decoded = tokenizer.batch_decode(out)

    for decodedText, promptText in zip(decoded, prompt):
        cleaned = decodedText.replace("<|endoftext|>", "")
        num_tokens.append(len(cleaned) - len(promptText))
        cleaned = cleaned.replace(promptText, "")
        answer = cleaned.split("\n\n")[0].strip()
        answers.append(answer)

    return answers, num_tokens

#In this function we making the evaluation for every single datapoint. During the generation we
#are making a statistics about the generation.
def eval(data, model, tokenizer, output_file, few_shot, batch_size):
    numberOfTokens = 0
    timeOfStart = 0
    results = []
    total_qs = len(data)
    correct = 0
    i = 0

    for batch_start in range(0, total_qs, batch_size):
        batch_end = min(batch_start + batch_size, total_qs)
        batch_data = data[batch_start:batch_end] 

        # Prepare batch inputs
        questions = [item['prompt'] for item in batch_data]
        contexts = [item['context'] for item in batch_data]
        answers = [item['response'] for item in batch_data]
        inputs = [f"{ctx}\n\nQ: {que}" for ctx, que in zip(contexts, questions)]
        
        # Generate outputs in a batch
        start_time = time.time()
        batch_guesses, batch_num_tokens = run_with_SQuAD(model, tokenizer, inputs, few_shot)
        end_time = time.time()
        timeOfStart += end_time - start_time

        # Process results 
        for guess, num_tokens, answer, question, context in zip(batch_guesses, batch_num_tokens, answers, questions, contexts):
            if guess and guess[-1] == '.' and answer[-1] != '.':
                guess = guess[:-1]
            numberOfTokens += num_tokens
            tkps = num_tokens / (end_time - start_time)
            is_correct = (answer.strip().lower() == guess.strip().lower())
            print(f"Question {i+1}/{total_qs}")
            print(f"Q: {question}")
            print(f"A: {answer}")
            print(f"?: {guess}")
            if is_correct:
                print(f"✅")
                correct += 1
            else:
                print(f"❌")
            print("="*80)
            result = {
                "idx": i,
                "question": question,
                "context": context,
                "answer": answer,
                "guess": guess,
                "is_correct": is_correct,
                "time": end_time - start_time,
                "num_tokens": num_tokens,
                "tokens_per_sec": tkps
            }
            results.append(result)
            i += 1
            
            if len(results) % 20 == 0:
                write_results(results, output_file)

    print(f"Accuracy: {correct / total_qs * 100}% -- {correct} correct and {total_qs - correct} incorrect")
    print(f"Number of tokens generated: {numberOfTokens} -- Time: {timeOfStart} -- Tokens-Per-Sec: {numberOfTokens / timeOfStart}")
    
#This function writes out the results.
def write_results(results, output_file):
    df = pd.DataFrame(results)
    df = df[["idx", "question", "context", "answer", "guess", "is_correct", "time", "num_tokens", "tokens_per_sec"]]
    print(f"Writing {output_file}")
    df.to_json(output_file, orient="records", lines=True)

# %% [markdown]
# ## 130m model

# %%
from transformers import MambaConfig, MambaForCausalLM, AutoTokenizer

tokenizer130m = AutoTokenizer.from_pretrained("state-spaces/mamba-130m-hf", padding_side='left')
model130m = MambaForCausalLM.from_pretrained("state-spaces/mamba-130m-hf")
tokenizer130m.eos_token = "<|endoftext|>"
tokenizer130m.pad_token = tokenizer130m.eos_token
# Out:
# tokenizer_config.json:   0%|          | 0.00/4.79k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# config.json:   0%|          | 0.00/895 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/517M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/137 [00:00<?, ?B/s]

# %%
eval(data[:100], model130m, tokenizer130m, "evalMamba130M.json", few_shot=False, batch_size=32)
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Question 1/100
# Q: How many yards did the Panthers get for the division championshipt game?
# A: 487
# ?: The Panthers got a total of 7.5 yards per carry
# ❌
# ================================================================================
# Question 2/100
# Q: What caused Jacksonville's tourism to become less desirable at the latter half of the 19th century?
# A: yellow fever outbreaks
# ?: The city's population grew rapidly and the city's economy was heavily reliant on tourism. The city's population grew from about 1,000 in 1846 to about 2,000 in 1877. The city's economy was heavily reliant on tourism. The city's economy was heavily reliant on tourism. The city's economy was heavily reliant on tourism. The city's economy was heavily reliant on tourism. The city's economy was heavily reliant on tourism. The city's economy was heavily reliant on tourism. The city's economy was heavily reliant on tourism. The city's economy was heavily reliant on tourism
# ❌
# ================================================================================
# Question 3/100
# Q: What are pharmacists in the United Kingdom being increasingly paid for?
# A: medicine use reviews
# ?: Pharmacists are paid in the United Kingdom for their work in the pharmaceutical industry. They are paid in the United States for their work in the United States
# ❌
# ================================================================================
# Question 4/100
# Q: Geoglyphs dating to what period were found in deforested land along the Amazon River?
# A: AD 0–1250
# ?: The earliest geoglyphs dating to the 15th century are found in the Amazon River. The earliest geoglyphs dating to the 15th century are found in the Amazon River. The earliest geoglyphs dating to the 15th century are found in the Amazon River. The earliest geoglyphs dating to the 15th century are found in the Amazon River. The earliest geoglyphs dating to the 15th century are found in the Amazon River. The earliest geoglyphs dating to the 15th century are found in the Amazon River. The earliest geoglyphs dating to the 15th century are found
# ❌
# ================================================================================
# Question 5/100
# Q: Who does a gender pay gap tend to favor?
# A: males in the labor market
# ?: Women
# ❌
# ================================================================================
# Question 6/100
# Q: What is the annual construction industry revenue in 2014?
# A: $960 billion
# ?: The annual construction industry revenue in 2014 was $1.1 billion
# ❌
# ================================================================================
# Question 7/100
# Q: Which sculpture by Michelangelo has a full-size replica in the Cast Courts?
# A: David
# ?: The statue of the Virgin Mary by Michelangelo is in the Cast Courts
# ❌
# ================================================================================
# Question 8/100
# Q: Richard Allen and Absalom Jones were licensed by St. George's Church in what year?
# A: 1784
# ?: 1836
# ❌
# ================================================================================
# Question 9/100
# Q: Where does the Rhine end?
# A: Hoek van Holland
# ?: The Rhine is the longest river in the world. It is the longest river in the world. It is the longest river in the world. It is the longest river in the world. It is the longest river in the world. It is the longest river in the world. It is the longest river in the world. It is the longest river in the world. It is the longest river in the world. It is the longest river in the world. It is the longest river in the world. It is the longest river in the world. It is the longest river in the world. It is the longest river in the world
# ❌
# ================================================================================
# Question 10/100
# Q: The V&A has the world's most comprehensive collection of sculptures from which period?
# A: post-classical European
# ?: The V&A has the world's largest collection of sculptures from around the world. The sculptures are made from the finest materials available, including marble, alabaster, stone, ivory, gesso, plaster, bronze, ceramics, wood (history of wood carving), ivory, gesso, plaster, bronze, ceramics, and terracotta
# ❌
# ================================================================================
# Question 11/100
# Q: Which country rationed gasoline and heating gas?
# A: Sweden
# ?: The United States
# ❌
# ================================================================================
# Question 12/100
# Q: The United States is divided into how many jurisdictions?
# A: five
# ?: The United States is divided into five jurisdictions: Africa, Central America, South America, Eastern Europe, and the Philippines. The United States is divided into five jurisdictions: Africa, Central America, South America, Eastern Europe, and the Philippines. The United States is divided into five jurisdictions: Africa, Central America, South America, Eastern Europe, and the Philippines. The United States is divided into five jurisdictions: Africa, Central America, South America, Eastern Europe, and the Philippines. The United States is divided into five jurisdictions: Africa, Central America, South America, Eastern Europe, and the Philippines. The United States is divided into five jurisdictions
# ❌
# ================================================================================
# Question 13/100
# Q: What is an example of a machine model that deviates from a generally accepted multi-tape Turing machine?
# A: random access machines
# ?: A machine model is a model that is not consistent with the standard multi-tape Turing machine
# ❌
# ================================================================================
# Question 14/100
# Q: What company developed the most successful steam engine indicator?
# A: Charles Porter
# ?: The most successful steam engine indicator company was the American Steam Engine Indicator Company (ASTEC). The company was founded in 1852 by John A. Porter, a steam engine engineer and inventor. The company was founded on the advice of the inventor, Charles Porter, who was a member of the American Steam Engine Manufacturers Association. Porter was a member of the American Steam Engine Manufacturers Association. Porter was a member of the American Steam Engine Manufacturers Association. Porter was a member of the American Steam Engine Manufacturers Association. Porter was a member of the American Steam Engine Manufacturers Association. Porter was a member of the American Steam Engine Manufact
# ❌
# ================================================================================
# Question 15/100
# Q: Who dates rocks, precisely, within the stratigraphic section?
# A: Geochronologists
# ?: The stratigraphic section is the sequence of rocks that are dated. The sequence is the sequence of rocks that are dated. The sequence is the sequence of rocks that are dated. The sequence is the sequence of rocks that are dated. The sequence is the sequence of rocks that are dated. The sequence is the sequence of rocks that are dated. The sequence is the sequence of rocks that are dated. The sequence is the sequence of rocks that are dated. The sequence is the sequence of rocks that are dated. The sequence is the sequence of rocks that are dated. The sequence is the sequence of rocks that are dated. The sequence is the
# ❌
# ================================================================================
# Question 16/100
# Q: Who formulated the idea of clonal selection theory of immunity?
# A: Frank Burnet
# ?: The idea of clonal selection theory of immunity was first formulated by Niels Jerne in the mid-1950s. He was a member of the American Academy of Microbiology and was the first to propose the idea of clonal selection theory of immunity
# ❌
# ================================================================================
# Question 17/100
# Q: What is the second most abundant element?
# A: helium
# ?: Oxygen
# ❌
# ================================================================================
# Question 18/100
# Q: what was invented in 1880 that revolutionized warfare?
# A: the machine gun
# ?: The machine gun was invented by a German engineer named Karl von Kühn. He was a German engineer who had been trained in the military and had been trained in the art of machine gunning. He was a very skilled engineer and he was able to design a machine gun that could fire a bullet at a distance of up to 100 yards. He was able to shoot a bullet at a distance of up to 100 yards
# ❌
# ================================================================================
# Question 19/100
# Q: When did Watt finish the development of his improvements to Newcomen's engine?
# A: 1775
# ?: In 1775, Watt's engine was completed. It was the first engine to be built in the United States
# ❌
# ================================================================================
# Question 20/100
# Q: What is the largest item from Italy that is part of the sculpture collection?
# A: Chancel Chapel
# ?: The largest sculpture in the collection is the Chancel Chapel from Santa Chiara Florence dated 1575 by Giulio da Sangallo it is 11.1 metres in height by 5.1 metres wide by 5.1 metres long by 3.1 metres wide. It includes a grand sculpted tabernacle by Antonio Rossellino, coloured terracotta decoration
# ❌
# ================================================================================
# Writing evalMamba130M.json
# Question 21/100
# Q: Antibodies are transferred to the gut of the infant through what means?
# A: Breast milk or colostrum
# ?: Antibodies are transferred to the gut of the infant through the placenta. Antibodies are transferred to the gut of the infant through the placenta. Antibodies are transferred to the gut of the infant through the placenta. Antibodies are transferred to the gut of the infant through the placenta. Antibodies are transferred to the gut of the infant through the placenta. Antibodies are transferred to the gut of the infant through the placenta. Antibodies are transferred to the gut of the infant through the placenta. Antibodies are transferred to the gut of the infant through the placenta. Antibodies are transferred to the gut of the infant through the placenta. Antibodies
# ❌
# ================================================================================
# Question 22/100
# Q: Which century was there a program to straighten the Rhine?
# A: 19th Century
# ?: The first straightening program was in the late 19th century. The first straightening program was in the late 19th century. The first straightening program was in the late 20th century. The first straightening program was in the late 20th century. The first straightening program was in the late 20th century. The first straightening program was in the late 20th century. The first straightening program was in the late 20th century. The first straightening program was in the late 20th century. The first straightening program was in the late 20th century. The first straightening program was in the late 20th
# ❌
# ================================================================================
# Question 23/100
# Q: Where was the first horse racetrack located?
# A: Pole Mokotowskie
# ?: The first horse racetrack in Poland was built in 1869 by the Polish-Lithuanian-Hungarian racehorse owner, Jan Dobrowolski. The racecourse was built in the city of Praga, and it was named after the city
# ❌
# ================================================================================
# Question 24/100
# Q: What did the Islamic State proclaim itself in 2014?
# A: a caliphate
# ?: The Islamic State is a caliphate. It is a state of Islamic law, and is a state of law. It is a state of law, and is a state of law. It is a state of law, and is a state of law. It is a state of law, and is a state of law. It is a state of law, and is a state of law. It is a state of law, and is a state of law. It is a state of law, and is a state of law. It is a state of law, and is a state of law. It is a state of law
# ❌
# ================================================================================
# Question 25/100
# Q: What plants don't need light to make chloroplasts?
# A: Gymnosperms
# ?: Plants that don't need light to make chloroplasts are not chloroplasts. They are chloroplasts, which are the cells that make chlorophyll
# ❌
# ================================================================================
# Question 26/100
# Q: Where was Dyrrachium located?
# A: the Adriatic
# ?: Dyrrachium was located in the city of Dyrrachium, in the province of Dyrrachium, in the province of Dyrrachium, in the province of Dyrrachium, in the province of Dyrrachium, in the province of Dyrrachium, in the province of Dyrrachium, in the province of Dyrrachium, in the province of Dyrrachium, in the province of Dyrrachium, in the province of Dyrrachium, in the province of Dyrrachium, in the province of Dyrrachium, in the province of Dy
# ❌
# ================================================================================
# Question 27/100
# Q: What is the expression used to denote a worst case complexity as expressed by time taken?
# A: O(n2)
# ?: The worst case complexity is the time taken to sort the list
# ❌
# ================================================================================
# Question 28/100
# Q: How would the capabilities approach achieve it's goal?
# A: through increasing functionings
# ?: The capabilities approach is a form of “capability” analysis. It is a method of analyzing the way in which people are able to achieve their goals. It is a method of analyzing the way people are able to achieve their goals. It is a method of analyzing the way people are able to achieve their goals. It is a method of analyzing the way people are able to achieve their goals. It is a method of analyzing the way people are able to achieve their goals. It is a method of analyzing the way people are able to achieve their goals. It is a method of analyzing the way people are able to achieve their goals. It
# ❌
# ================================================================================
# Question 29/100
# Q: Within what variable is L constrained according to the space hierarchy theorem?
# A: PSPACE
# ?: The space hierarchy theorem tells us that L is strictly contained in PSPACE
# ❌
# ================================================================================
# Question 30/100
# Q: What are the "Big Five" animals in Kenya?
# A: lion, leopard, buffalo, rhinoceros, and elephant
# ?: The Big Five are the five most important animals in Kenya. They are the largest animals in the country, with a population of over 1,000,000. They are the largest animals in the country, with a population of over 1,000,000. They are the largest animals in the country, with a population of over 1,000,000. They are the largest animals in the country, with a population of over 1,000,000. They are the largest animals in the country, with a population of over 1,000,000. They are the largest animals in the country, with a population of over 1,
# ❌
# ================================================================================
# Question 31/100
# Q: What is another way of referring to stators?
# A: static discs
# ?: A stator is a gearbox that is used to rotate a shaft. A gearbox is a gear that is used to rotate a shaft. A gearbox is a gear that is used to rotate a shaft. A gearbox is a gear that is used to rotate a shaft. A gearbox is a gear that is used to rotate a shaft. A gearbox is a gear that is used to rotate a shaft. A gearbox is a gear that is used to rotate a shaft. A gearbox is a gear that is used to rotate a shaft. A gearbox is a gear that is used to rotate a shaft. A
# ❌
# ================================================================================
# Question 32/100
# Q: When was the new two-year affiliate agreement approved?
# A: 2002
# ?: The new two-year affiliate agreement was approved on July 1, 2012
# ❌
# ================================================================================
# Question 33/100
# Q: What type of materials inside the cabin were removed to help prevent more fire hazards in the future?
# A: flammable cabin and space suit materials
# ?: The Block II spacecraft was designed to be a safe, reliable, and reliable spacecraft. The Block II spacecraft was designed to be a safe, reliable, and reliable spacecraft. The Block II spacecraft was designed to be a safe, reliable, and reliable spacecraft. The Block II spacecraft was designed to be a safe, reliable, and reliable spacecraft. The Block II spacecraft was designed to be a safe, reliable, and reliable spacecraft. The Block II spacecraft was designed to be a safe, reliable, and reliable spacecraft. The Block II spacecraft was designed to be a safe, reliable, and reliable spacecraft. The Block II spacecraft was designed to be a
# ❌
# ================================================================================
# Question 34/100
# Q: How many nations contain "Amazonas" in their names?
# A: States or departments in four nations contain "Amazonas" in their names.
# ?: The Amazon is a name that is used by many nations in the Amazon basin. The Amazon basin is a large area of rainforest that covers an area of about 1,000 square kilometres (450 sq mi). The Amazon basin is divided into four nations: Brazil, Colombia, Ecuador, and Peru. The Amazon basin is also known as the Amazonia or Amazonia.
# ❌
# ================================================================================
# Question 35/100
# Q: What was Tesla's position with Westinghouse?
# A: consultant
# ?: Westinghouse was a major investor in Tesla's business. Tesla was a major investor in Westinghouse's business. Westinghouse was also a major investor in Tesla's business
# ❌
# ================================================================================
# Question 36/100
# Q: What year were the first Doctor Who stories available on CD?
# A: 1999
# ?: The first Doctor Who stories were released in 1999
# ❌
# ================================================================================
# Question 37/100
# Q: What is the term for a task that generally lends itself to being solved by a computer?
# A: computational problems
# ?: A task is a task that is in principle amenable to being solved by a computer
# ❌
# ================================================================================
# Question 38/100
# Q: What was happening to subscriber numbers in other areas of europe?
# A: flattened
# ?: The number of subscribers in Europe has been declining for the last few years. The number of subscribers in the UK has been growing at a rate of about 1.5% per year since the beginning of the year
# ❌
# ================================================================================
# Question 39/100
# Q: Dutch architect Janjaap Ruijssenaars's performative architecture 3D-printed building is scheduled to be built when?
# A: Working versions of 3D-printing building technology are already printing
# ?: In 2014, the Dutch architect Janjaap Ruijssenaars's 3D-printing architecture will be built in a short time. The 3D-printed building will be constructed in a short time
# ❌
# ================================================================================
# Question 40/100
# Q: When was the most recent Super Bowl hosted in the South Florida/Miami area?
# A: 2010
# ?: The Super Bowl was held in Miami in 1985. The stadium was built in the early 1980s and was the home of the Miami Dolphins. The stadium was renovated in the late 1980s and was the home of the Miami Dolphins. The stadium was the home of the Miami Dolphins. The Miami Dolphins were the first team to play in the stadium
# ❌
# ================================================================================
# Writing evalMamba130M.json
# Question 41/100
# Q: The atomic number of the periodic table for oxygen?
# A: 8
# ?: The atomic number of the periodic table for oxygen is 8
# ❌
# ================================================================================
# Question 42/100
# Q: How were enemy prisoners used tactically by Mongol armies?
# A: driving them in front of the army
# ?: The Mongol army was not a large army, but it was a large army of men, and it was not a small army. The Mongol army was not a large army, but it was a large army of men, and it was not a small army. The Mongol army was not a large army, but it was a large army of men, and it was not a small army
# ❌
# ================================================================================
# Question 43/100
# Q: What is the CJEU's duty?
# A: ensure that in the interpretation and application of the Treaties the law is observed
# ?: The CJEU is the highest court in the EU. It is the only court in the EU that has the authority to interpret the Treaties. It is the only court that has the authority to interpret the Treaties. It is the only court that has the authority to interpret the Treaties. It is the only court that has the authority to interpret the Treaties. It is the only court that has the authority to interpret the Treaties. It is the only court that has the authority to interpret the Treaties. It is the only court that has the authority to interpret the Treaties. It is the only court that has the
# ❌
# ================================================================================
# Question 44/100
# Q: Who was an important figure in the twentieth-century Islamic revival in India?
# A: Sayyid Abul Ala Maududi
# ?: The first major figure to be recognized as a major figure in the revival of Islam was the late Maududi, who was a leading figure in the revival of Islam in India. Maududi was a leading figure in the revival of Islam in India, and was a major figure in the revival of Islam in India. He was a leading figure in the revival of Islam in India, and was a leading figure in the revival of Islam in India. He was a leading figure in the revival of Islam in India, and was a leading figure in the revival of Islam in India. He was a leading figure in the revival of Islam in India
# ❌
# ================================================================================
# Question 45/100
# Q: When did the ban on cigarette advertising take effect for television networks?
# A: January 2, 1971
# ?: The ban was effective from January 2, 1971, to January 2, 1972
# ❌
# ================================================================================
# Question 46/100
# Q: In what form is oxygen transported in smaller containers?
# A: compressed gas
# ?: Oxygen is transported in small containers, which are usually made of plastic or metal. The containers are usually made of plastic or metal, and are filled with oxygen. The oxygen is then transported in a tank, which is filled with compressed air. The oxygen is then compressed and sent to the patient
# ❌
# ================================================================================
# Question 47/100
# Q: When rich countries trade with poor countries, whose wages increase?
# A: workers in the poor countries
# ?: The United States has a large trade deficit with China, and the United States has a large trade deficit with China. The United States has a large trade deficit with China, and the United States has a large trade deficit with China. The United States has a large trade deficit with China, and the United States has a large trade deficit with China. The United States has a large trade deficit with China, and the United States has a large trade deficit with China. The United States has a large trade deficit with China, and the United States has a large trade deficit with China. The United States has a large trade deficit with China, and the
# ❌
# ================================================================================
# Question 48/100
# Q: Who led the Science and Environmental Policy Project?
# A: Fred Singer
# ?: The IPCC
# ❌
# ================================================================================
# Question 49/100
# Q: In what year did the NFL switch to a 16-game regular season?
# A: 1978
# ?: The NFL began the season with a 16-game regular season, but the league changed its rules to allow a 16-game regular season to begin on the first Sunday of the regular season. The league also changed the rules to allow a 16-game regular season to begin on the first Sunday of the regular season. The league also changed the rules to allow a 16-game regular season to begin on the first Sunday of the regular season
# ❌
# ================================================================================
# Question 50/100
# Q: What does computational complexity theory most specifically seek to answer?
# A: computational problems
# ?: The computational complexity of a problem is the number of instances of the problem that can be solved in polynomial time
# ❌
# ================================================================================
# Question 51/100
# Q: What was the final score of Super Bowl 50?
# A: 24–10
# ?: The final score of Super Bowl 50 was 49–42
# ❌
# ================================================================================
# Question 52/100
# Q: What did Luther call the mass instead of sacrifice?
# A: a gift
# ?: The Mass
# ❌
# ================================================================================
# Question 53/100
# Q: What did Queen Elizabeth II open in Newcastle in 1981?
# A: A bridge
# ?: The first public open-air station in the UK was opened in Newcastle in 1981. The station was designed by the British Railways company, and was built by the Tyne and Wear Metro system. The station was opened in 1981, and was the first public open-air station in the UK to have underground tracks and tunnels constructed through Newcastle city centre. The station was the first in the UK to have underground stations, and was the first in the UK to have open-air stations, as the Metro system was designed and constructed by the Tyne and Wear Metro system. The station was the first in the UK to have underground
# ❌
# ================================================================================
# Question 54/100
# Q: What kind of disorders are the result of an overactive immune response?
# A: autoimmune disorders
# ?: The immune system is a complex system that is constantly changing. The immune system is constantly changing, and it is not always the same. The immune system is constantly changing, and it is not always the same
# ❌
# ================================================================================
# Question 55/100
# Q: Where hotel did the Panthers stay at?
# A: San Jose Marriott.
# ?: The hotel was at the Marriott in Santa Clara.
# ❌
# ================================================================================
# Question 56/100
# Q: Why did Westinghouse not secure a patent for a similar motor?
# A: decided Tesla's patent would probably control the market
# ?: Tesla was not a patent-holder. He was a mechanical engineer who had been working on a similar motor for a long time. He had been working on a similar motor for a long time, and had been working on a similar motor for a long time. He had been working on a similar motor for a long time. He had been working on a similar motor for a long time. He had been working on a similar motor for a long time. He had been working on a similar motor for a long time. He had been working on a similar motor for a long time. He had been working on a similar motor for a long
# ❌
# ================================================================================
# Question 57/100
# Q: What words to they think are linked to the work Kenya?
# A: Kirinyaga, Kirenyaa and Kiinyaa
# ?: The words Kenya is a common name for the country. Kenya is a country of about 1.5 million people. Kenya is a country of about 1.5 million people. Kenya is a country of about 1.5 million people. Kenya is a country of about 1.5 million people. Kenya is a country of about 1.5 million people. Kenya is a country of about 1.5 million people. Kenya is a country of about 1.5 million people. Kenya is a country of about 1.5 million people. Kenya is a country of about 1.5 million people. Kenya is a country of about 1.5
# ❌
# ================================================================================
# Question 58/100
# Q: When was the first known historical reference to immunity?
# A: Athens in 430 BC
# ?: In the early 20th century, when the first vaccine was developed
# ❌
# ================================================================================
# Question 59/100
# Q: What was the name of the Mongol Empire's legal code?
# A: Yassa
# ?: The Mongol Empire's legal code was called the Yassa. The Mongol Empire's legal code was called the Yassa. The Mongol Empire's legal code was called the Yassa. The Mongol Empire's legal code was called the Yassa. The Mongol Empire's legal code was called the Yassa. The Mongol Empire's legal code was called the Yassa. The Mongol Empire's legal code was called the Yassa. The Mongol Empire's legal code was called the Yassa. The Mongol Empire's legal code was called the Yassa. The Mongol Empire's legal code was called the Y
# ❌
# ================================================================================
# Question 60/100
# Q: When had the Six Ministries existed?
# A: since the Sui and Tang dynasties
# ?: The Six Ministries were established in the Yuan period. They were established in the early Yuan period, and were established in the early Ming period. They were established to provide a centralized administrative structure for the Mongolian empire
# ❌
# ================================================================================
# Writing evalMamba130M.json
# Question 61/100
# Q: How to Baptized Members become Professing Members?
# A: confirmation and sometimes the profession of faith
# ?: Baptized Members are those who have been baptized as an infant or adult, but who have not subsequently professed their own faith. They are Baptized Members who have not previously professed their own faith. Individuals who were previously baptized as an infant or adult, but who have not subsequently professed their own faith. Individuals who were not previously baptized as an infant or adult, but who have not subsequently professed their own faith. Individuals who were not previously baptized as an infant or adult, but who have not subsequently professed their own faith. Individuals who were not previously baptized as an infant or adult, but who
# ❌
# ================================================================================
# Question 62/100
# Q: After asking if the books were his, what else did Eck ask Luther?
# A: stood by their contents
# ?: Luther said that the books were his
# ❌
# ================================================================================
# Question 63/100
# Q: When did the Pope warned Luther of excommunication?
# A: 15 June 1520
# ?: Luther was excommunicated by Pope Leo X on 15 June 1520, in the bull Decet Romanum Pontificum. Luther was excommunicated by Pope Leo X on 15 June 1520, in the bull Decet Romanum Pontificum
# ❌
# ================================================================================
# Question 64/100
# Q: When large groups of people all boycott a system or don't pay taxes it can be considered?
# A: coercive
# ?: It is not a form of boycott. It is a form of protest
# ❌
# ================================================================================
# Question 65/100
# Q: What ABC action series went up against NBC's variety shows in Fall 1957?
# A: Zorro
# ?: ABC's series of "The Big Bang Theory" was a series of three episodes, each of which was a half-hour. The first episode was a "series of three" with a "series of three" ending. The second episode was a "series of three" with a "series of three" ending. The third episode was a "series of three" with a "series of three" ending. The fourth episode was a "series of three" with a "series of three" ending. The fifth episode was a "series of three" with a "series of three" ending. The sixth episode was a "series
# ❌
# ================================================================================
# Question 66/100
# Q: What was the significance of victory at Forth Niagara for British?
# A: cut off the French frontier forts further to the west and south
# ?: The victory was a decisive one for the British. The British were able to capture Fort Niagara and the surrounding area, and the British were able to capture the French fort of Montcalm. The British were able to capture the French fort of Ticonderoga, and the French were able to capture the French fort of Quebec
# ❌
# ================================================================================
# Question 67/100
# Q: What is the Latin name for Black Death?
# A: atra mors
# ?: The Latin name for Black Death is Black Death
# ❌
# ================================================================================
# Question 68/100
# Q: What are the phagocytes that are located in tissues in contact with the external environment called?
# A: Dendritic cells
# ?: The phagocytes are the cells that are located in the tissues that are contacted by the external environment. They are the cells that are located in the tissues that are contacted by the external environment. They are the cells that are located in the tissues that are contacted by the external environment
# ❌
# ================================================================================
# Question 69/100
# Q: What profession was Nathan Alterman?
# A: poet
# ?: He was a painter
# ❌
# ================================================================================
# Question 70/100
# Q: What type of vote must the Parliament have to either block or suggest changes to the Commission's proposals?
# A: a majority
# ?: The Parliament must vote to block or suggest changes to the Commission's proposals. The Parliament must vote to block or suggest changes to the Commission's proposals. The Parliament must vote to block or suggest changes to the Commission's proposals. The Parliament must vote to block or suggest changes to the Commission's proposals. The Parliament must vote to block or suggest changes to the Commission's proposals. The Parliament must vote to block or suggest changes to the Commission's proposals. The Parliament must vote to block or suggest changes to the Commission's proposals. The Parliament must vote to block or suggest changes to the Commission's proposals. The Parliament must vote to block or suggest
# ❌
# ================================================================================
# Question 71/100
# Q: What percentage of money raised was earmarked for causes in the San Francisco area?
# A: 25 percent
# ?: The San Francisco area is the largest in the country, and the largest in the country. The San Francisco Bay Area is the largest in the country, and the largest in the country
# ❌
# ================================================================================
# Question 72/100
# Q: In which year was the Musical Instruments gallery closed?
# A: 2010
# ?: The Musical Instruments gallery closed on 1 January 2010
# ❌
# ================================================================================
# Question 73/100
# Q: What scientific field's theory has received contributions from the steam engine?
# A: thermodynamic
# ?: The steam engine was developed by the French engineer Pierre-Joseph-Joseph Boulanger in the late 18th century. He was the first to develop a steam engine that could be operated at high pressure and at high temperatures. The steam engine was the first steam engine to be used in the production of electricity. The steam engine was the first steam engine to be used in the production of electricity. The steam engine was the first steam engine to be used in the production of electricity. The steam engine was the first steam engine to be used in the production of electricity. The steam engine was the first steam engine to be used in the production of
# ❌
# ================================================================================
# Question 74/100
# Q: What type of organization would need large quantities of pure oxygen?
# A: hospitals
# ?: The most common type of oxygen storage is in tanks. The tanks are used to store oxygen in a liquid form, which is then transported to the patient. The oxygen is then stored in a tank, which is filled with pure oxygen. The tank is filled with oxygen, which is then pumped into the patient. The oxygen is then stored in a tank, which is filled with pure oxygen. The oxygen is then pumped into the patient, which is then heated to a temperature of about 100 °C (250 °F). The oxygen is then stored in a tank, which is filled with pure oxygen. The oxygen is then pumped into the patient
# ❌
# ================================================================================
# Question 75/100
# Q: How much Saharan dust falls over the Amazon basin each year?
# A: 27.7 million tons
# ?: The Saharan dust is transported by wind, and is mostly in the form of dust particles. The amount of dust is a function of the wind speed and direction, and the amount of dust is a function of the wind speed and direction
# ❌
# ================================================================================
# Question 76/100
# Q: How long after a banquet with Tugh Temur did Kusala die?
# A: four days
# ?: Tugh Temur died on the third day of the banquet. He was buried in the city of Shangdu
# ❌
# ================================================================================
# Question 77/100
# Q: What type of people were being brought back to the way of truth?
# A: misguided
# ?: The Wittenberg jurist was a Lutheran. He was a member of the Lutheran Church in America
# ❌
# ================================================================================
# Question 78/100
# Q: What did the Greek root pharmakos imply?
# A: sorcery or even poison
# ?: The Greek word pharma (φάρμακος) derives from pharmakon meaning "drug", "poison". In addition to pharma responsibilities, the pharma (as it was referred to) often operated through a retail shop which, in addition to ingredients for medicines and a range of services that are now performed solely by other specialists, also offered general medical advice and a range of services that are not listed. The pharmas also operated under a variety of other names, though their practices were generally more akin to a modern pharmacy, in English the term pharmacy would today be considered outdated or only approprate to meet
# ❌
# ================================================================================
# Question 79/100
# Q: What was Fort Caroline renamed to after the Spanish attack?
# A: San Mateo
# ?: Fort Caroline was named after the Spanish explorer and governor of Florida, Jean Ribault
# ❌
# ================================================================================
# Question 80/100
# Q: Which territory did Jochi try to protect that may have led to a dispute with his brothers?
# A: Urgench
# ?: The territory of the Khanate of Urgench, which was ruled by the Khan of Khorasan, was a part of the Khanate of Khorasan. It was a territory that was ruled by the Khan of Khorasan, and it was ruled by the Khan of Khorasan
# ❌
# ================================================================================
# Writing evalMamba130M.json
# Question 81/100
# Q: What ranking does the Super Bowl 50 halftime show have on the list of most watched TV broadcasts?
# A: third
# ?: The Super Bowl 50 halftime show has the highest ranking, with a total of 1,935,000 viewers. The Super Bowl 50 halftime show has the highest ranking, with a total of 1,935,000 viewers
# ❌
# ================================================================================
# Question 82/100
# Q: What music did the fourth soundtrack feature?
# A: music from the 2008–2010 specials
# ?: The soundtrack for Series 5 featured music from the third and fourth featured tracks from the first two series. The fourth soundtrack featured music from the third and fourth featured tracks from the fourth series
# ❌
# ================================================================================
# Question 83/100
# Q: What administration did Ludwig Mies van der Rohe designa buiding?
# A: School of Social Service Administration
# ?: Ludwig Mies van der Rohe was a German architect who designed the first buildings on campus. He was a member of the German faculty of the University of Chicago, and he was also a member of the German faculty of the University of California, Berkeley. He was also a member of the German faculty of the University of California, Los Angeles
# ❌
# ================================================================================
# Question 84/100
# Q: What was Manning's passer rating for the 2015 season?
# A: 67.9
# ?:
# ❌
# ================================================================================
# Question 85/100
# Q: Issues dealt with at Westminster are not ones who is able to deal with?
# A: Scottish Parliament
# ?: The Scottish Parliament is not able to deal with issues dealt with at Westminster
# ❌
# ================================================================================
# Question 86/100
# Q: What was the wedding date?
# A: 12 May 1191
# ?: The wedding was held on 12 May 1191 at the Chapel of St. George and it was attended by Richard the Lion-Heart and his wife, Queen of Cyprus, Queen of England and Queen of Navarre
# ❌
# ================================================================================
# Question 87/100
# Q: What did the development of this fertile soil provide in hostile environment?
# A: agriculture and silviculture
# ?: The soil was fertile, but it was not a perfect soil. The soil was not perfectly sandy, but it was very sandy. The soil was very acidic, and it was acidic because it was a very acidic soil. The soil was very acidic because it was acidic. The soil was acidic because it was acidic. The soil was acidic because it was acidic. The soil was acidic because it was acidic. The soil was acidic because it was acidic. The soil was acidic because it was acidic. The soil was acidic because it was acidic. The soil was acidic because it was acidic. The soil was acidic because it was acidic. The soil
# ❌
# ================================================================================
# Question 88/100
# Q: Who did the North declare for during the English civil war?
# A: the King
# ?: The North declared for the King in 1644
# ❌
# ================================================================================
# Question 89/100
# Q: Which country does the Rhine encounter it's main tributaries?
# A: Germany
# ?: The Rhine is the main tributary of the Rhine. It drains to the Rhine via the Moselle, the Vosges and the Jura Mountains. The Rhine drains to the North Sea via the North Sea. The Rhine drains to the North Sea via the North Sea. The Rhine drains to the North Sea via the North Sea. The Rhine drains to the North Sea via the North Sea. The Rhine drains to the North Sea via the North Sea. The Rhine drains to the North Sea via the North Sea. The Rhine drains to the North Sea
# ❌
# ================================================================================
# Question 90/100
# Q: What French animation studio did ABC purchase in 1993?
# A: DIC Entertainment
# ?: DIC Entertainment
# ✅
# ================================================================================
# Question 91/100
# Q: What rive joins the Rhine in Duisburg?
# A: Ruhr
# ?: The Ruhr is a river that flows through the Rhine valley. It is a tributary of the Rhine, which flows through the Ruhrgebiet, the region of the Ruhrgebiet, the Ruhrgebiet and the Ruhrgebiet. The Ruhrgebiet is the largest river in the Rhine basin, and the largest river in Germany. The Ruhrgebiet is the largest river in Germany, and the largest river in the Rhine basin. The Ruhrgebiet is the largest river in Germany, and the Ruhrgebiet is the largest river in Germany. The Ruhrgebiet
# ❌
# ================================================================================
# Question 92/100
# Q: Which animal's venom did Pierre-Louis Moreau de Maupertuis work with?
# A: scorpion
# ?: The venom of the scorpion venom is the most potent of all the venomous animals. It is the most potent of all the venomous animals. It is the most potent of all the venomous animals. It is the most potent of all the venomous animals. It is the most potent of all the venomous animals. It is the most potent of all the venomous animals. It is the most potent of all the venomous animals. It is the most potent of all the venomous animals. It is the most potent of all the venomous animals. It is the most potent of all the venomous animals. It
# ❌
# ================================================================================
# Question 93/100
# Q: In the capabilities approach, grow and income are considered a means to an end rather than what?
# A: the end itself
# ?: The capabilities approach is a form of “capability” theory. It is a theory that focuses on the way in which people are able to achieve their goals. It is a theory that focuses on the way in which people are able to achieve their goals. It is a theory that focuses on the way in which people are able to achieve their goals. It is a theory that focuses on the way in which people are able to achieve their goals. It is a theory that focuses on the way in which people are able to achieve their goals. It is a theory that focuses on the way in which people are able to achieve their goals. It
# ❌
# ================================================================================
# Question 94/100
# Q: Where are Jersey and Guernsey
# A: Channel Islands
# ?: Jersey and Guernsey are two islands in the Atlantic Ocean. Jersey is the largest island in the Atlantic Ocean and is the largest island in the world. Jersey is the largest island in the world and is the largest island in the world. Jersey is the largest island in the world and is the largest island in the world. Jersey is the largest island in the world and is the largest island in the world. Jersey is the largest island in the world and is the largest island in the world. Jersey is the largest island in the world and is the largest island in the world. Jersey is the largest island in the world and is the largest
# ❌
# ================================================================================
# Question 95/100
# Q: What was the boat called?
# A: teleautomaton
# ?: The Teleautomaton
# ❌
# ================================================================================
# Question 96/100
# Q: What did the SNP publicly opine about the oil revenues?
# A: not benefitting Scotland as much as they should
# ?: The SNP's response was that the revenues were not sufficient to fund the Scottish Government's budget. The SNP's response was that the revenues were sufficient to fund the Scottish Government's budget
# ❌
# ================================================================================
# Question 97/100
# Q: How many days after Gagarin's flight did the US House Committee on Science and Astronautics meet?
# A: one day
# ?: The committee met on April 12, 1961
# ❌
# ================================================================================
# Question 98/100
# Q: How can function problems typically be restated?
# A: decision problems
# ?: The function problem is a problem in the sense that it is a problem in the sense that it is a problem in the sense that it is a problem in the sense that it is a problem in the sense that it is a problem in the sense that it is a problem in the sense that it is a problem in the sense that it is a problem in the sense that it is a problem in the sense that it is a problem in the sense that it is a problem in the sense that it is a problem in the sense that it is a problem in the sense that it is a problem in the sense that it is a problem in the
# ❌
# ================================================================================
# Question 99/100
# Q: What does Fortiter Defendit Triumphans mean?
# A: Triumphing by a brave defence
# ?: Fortiter Defendit means to defend the town from the enemy
# ❌
# ================================================================================
# Question 100/100
# Q: Recent studies believe  that ctenophores are the sister lineage to what?
# A: all other animals
# ?: The ctenophores are the sister to all other animal phyla
# ❌
# ================================================================================
# Writing evalMamba130M.json
# Accuracy: 1.0% -- 1 correct and 99 incorrect
# Number of tokens generated: 53556 -- Time: 22.22880458831787 -- Tokens-Per-Sec: 2409.306347861181

# %%
eval(data[:100], model130m, tokenizer130m, "evalMamba130M_Few_shot.json", few_shot=True, batch_size=32)
# Out:
# Question 1/100
# Q: How many yards did the Panthers get for the division championshipt game?
# A: 487
# ?: The Panthers scored a total of 1,923 yards on the ground, including 1,923 yards on the ground in the divisional round
# ❌
# ================================================================================
# Question 2/100
# Q: What caused Jacksonville's tourism to become less desirable at the latter half of the 19th century?
# A: yellow fever outbreaks
# ?: The city's population was growing rapidly, and the city's economy was in decline. The city's population was growing at a rate of about 1.5% per year, and the city's population was growing at a rate of about 1.5% per year. The city's population was growing at a rate of about 1.5% per year. The city's population was growing at a rate of about 1.5% per year. The city's population was growing at a rate of about 1.5% per year. The city's population was growing at a rate of about 1.5% per year. The city
# ❌
# ================================================================================
# Question 3/100
# Q: What are pharmacists in the United Kingdom being increasingly paid for?
# A: medicine use reviews
# ?: Pharmacists are paid in the United Kingdom for their work in the pharmaceutical industry. They are paid in the United States for their work in the United States
# ❌
# ================================================================================
# Question 4/100
# Q: Geoglyphs dating to what period were found in deforested land along the Amazon River?
# A: AD 0–1250
# ?: The earliest known geoglyphs dating to the 15th century are found in the Amazon River, which is now a major river in the Amazon Basin. The earliest known geoglyphs dating to the 15th century are found in the Amazon River, which is now a major river in the Amazon Basin. The earliest known geoglyphs dating to the 15th century are found in the Amazon River, which is now a major river in the Amazon Basin. The earliest known geoglyphs dating to the 15th century are found in the Amazon River, which is now a major river in the Amazon Basin. The earliest known ge
# ❌
# ================================================================================
# Question 5/100
# Q: Who does a gender pay gap tend to favor?
# A: males in the labor market
# ?: The gender pay gap is a problem in many countries. In the United States, the gender pay gap is the largest in the world. In the United Kingdom, the gender pay gap is the largest in the world. In the United States, the gender pay gap is the largest in the world
# ❌
# ================================================================================
# Question 6/100
# Q: What is the annual construction industry revenue in 2014?
# A: $960 billion
# ?: The annual construction industry revenue in 2014 was $1.1 billion, with an estimated $1.2 billion in annual revenue
# ❌
# ================================================================================
# Question 7/100
# Q: Which sculpture by Michelangelo has a full-size replica in the Cast Courts?
# A: David
# ?: The statue of Michelangelo by Michelangelo is in the Cast Courts
# ❌
# ================================================================================
# Question 8/100
# Q: Richard Allen and Absalom Jones were licensed by St. George's Church in what year?
# A: 1784
# ?: 1836
# ❌
# ================================================================================
# Question 9/100
# Q: Where does the Rhine end?
# A: Hoek van Holland
# ?: The Rhine is the longest river in the world, measuring 1,927 km (1,000 miles) and the longest river in the world. It is the longest river in the world, measuring 1,927 km (1,000 miles) and the longest river in the world, measuring 1,927 km (1,000 miles)
# ❌
# ================================================================================
# Question 10/100
# Q: The V&A has the world's most comprehensive collection of sculptures from which period?
# A: post-classical European
# ?: The V&A has the world's largest collection of sculptures from which period. The V&A has the world's largest collection of sculptures from which period. The V&A has the world's largest collection of sculptures from which period. The V&A has the world's largest collection of sculptures from which period. The V&A has the world's largest collection of sculptures from which period. The V&A has the world's largest collection of sculptures from which period. The V&A has the world's largest collection of sculptures from which period. The V&A has the world's largest collection of sculptures from which period
# ❌
# ================================================================================
# Question 11/100
# Q: Which country rationed gasoline and heating gas?
# A: Sweden
# ?: Germany
# ❌
# ================================================================================
# Question 12/100
# Q: The United States is divided into how many jurisdictions?
# A: five
# ?: The United States is divided into five jurisdictions: North America, Europe, Asia, Africa, and Latin America. The United States is divided into five jurisdictions: North America, Europe, Asia, Africa, and Latin America
# ❌
# ================================================================================
# Question 13/100
# Q: What is an example of a machine model that deviates from a generally accepted multi-tape Turing machine?
# A: random access machines
# ?: A machine model is a model that is not a machine. It is a machine that is not a machine. It is a machine that is not a machine. It is a machine that is not a machine. It is a machine that is not a machine. It is a machine that is not a machine. It is a machine that is not a machine. It is a machine that is not a machine. It is a machine that is not a machine. It is a machine that is not a machine. It is a machine that is not a machine. It is a machine that is not a machine. It is a machine that is
# ❌
# ================================================================================
# Question 14/100
# Q: What company developed the most successful steam engine indicator?
# A: Charles Porter
# ?: The first steam engine indicator was the steam engine indicator, which was developed by the American steam engine company, the American Steam Engine Company. The indicator was developed by the American Steam Engine Company in the early 1900s. The indicator was developed by the American Steam Engine Company in the early 1900s. The indicator was developed by the American Steam Engine Company. The indicator was developed by the American Steam Engine Company. The indicator was developed by the American Steam Engine Company
# ❌
# ================================================================================
# Question 15/100
# Q: Who dates rocks, precisely, within the stratigraphic section?
# A: Geochronologists
# ?: The oldest rocks are found in the core of the stratigraphic section, which is the oldest section of the stratigraphic section. The oldest rocks are found in the core of the stratigraphic section
# ❌
# ================================================================================
# Question 16/100
# Q: Who formulated the idea of clonal selection theory of immunity?
# A: Frank Burnet
# ?: The clonal selection theory of immunity was developed by Dr. John H. Berman in the late 1950s. He was a pioneer in the field of immunology, and he was the first to propose the clonal selection theory of immunity. He was also the first to propose the clonal selection theory of immunity in the context of the immune system
# ❌
# ================================================================================
# Question 17/100
# Q: What is the second most abundant element?
# A: helium
# ?: Oxygen
# ❌
# ================================================================================
# Question 18/100
# Q: what was invented in 1880 that revolutionized warfare?
# A: the machine gun
# ?: The first machine gun was invented in 1880 by a German engineer, who had been working in the United States for many years. The machine gun was a small, lightweight, and highly effective weapon. It was the first weapon to be used in the field of warfare
# ❌
# ================================================================================
# Question 19/100
# Q: When did Watt finish the development of his improvements to Newcomen's engine?
# A: 1775
# ?: Newcomen's engine was completed in 1814. Watt's engine was completed in 1817
# ❌
# ================================================================================
# Question 20/100
# Q: What is the largest item from Italy that is part of the sculpture collection?
# A: Chancel Chapel
# ?: The largest item from Italy is the Chancel Chapel from Santa Chiara Florence dated 1575 by Francesco Fanelli, 1495–1575, it is 5.5 metres in height by 5.5 metres wide by 5.5 metres deep
# ❌
# ================================================================================
# Writing evalMamba130M_Few_shot.json
# Question 21/100
# Q: Antibodies are transferred to the gut of the infant through what means?
# A: Breast milk or colostrum
# ?: Antibodies are transferred to the gut of the infant through the placenta. Antibodies are transferred to the gut of the infant through the placenta. Antibodies are transferred to the gut of the infant through the placenta. Antibodies are transferred to the gut of the infant through the placenta. Antibodies are transferred to the gut of the infant through the placenta. Antibodies are transferred to the gut of the infant through the placenta. Antibodies are transferred to the gut of the infant through the placenta. Antibodies are transferred to the gut of the infant through the placenta. Antibodies are transferred to the gut of the infant through the placenta. Antibodies
# ❌
# ================================================================================
# Question 22/100
# Q: Which century was there a program to straighten the Rhine?
# A: 19th Century
# ?: The Rhine was straightened in the 17th century. The first straightening program was in the 17th century
# ❌
# ================================================================================
# Question 23/100
# Q: Where was the first horse racetrack located?
# A: Pole Mokotowskie
# ?: The first horse racing track in Poland was built in 1872 by the Polish-American businessman and politician Władysław Gomułka. It was named after the Polish-American businessman and politician, who was the first president of the Polish-American Association
# ❌
# ================================================================================
# Question 24/100
# Q: What did the Islamic State proclaim itself in 2014?
# A: a caliphate
# ?: The Islamic State is a terrorist organization, which is a term used by the United States and other countries to describe a group of extremists who have been trained to wage war against the United States and its allies. The group's name is derived from the Arabic word for "terrorist", which is a term used by the United States and its allies to describe a group of extremists who have been trained to wage war against the United States and its allies. The group's name is derived from the Arabic word for "terrorist", which is a term used by two extremist militant groups, namely al-Qaeda and the Islamic State
# ❌
# ================================================================================
# Question 25/100
# Q: What plants don't need light to make chloroplasts?
# A: Gymnosperms
# ?: Plants that don't need light to make chloroplasts are not chloroplasts. They are chloroplasts, which are chlorophyll-containing chloroplasts. Chloroplasts are chlorophyll-containing chloroplasts that are chlorophyll-containing chloroplasts. Chloroplasts are chlorophyll-containing chloroplasts that are chlorophyll-containing chloroplasts. Chloroplasts are chloroplasts that are chloroplasts. Chloroplasts are chloroplasts that are chloroplasts. Chloroplasts are chloroplasts that are chloroplasts. Chloroplasts are chloroplasts that
# ❌
# ================================================================================
# Question 26/100
# Q: Where was Dyrrachium located?
# A: the Adriatic
# ?: In the city of Dyrrachium, in the city of Dyrrachium, in the city of Dyrrachium, in the city of Dyrrachium, in the city of Dyrrachium, in the city of Dyrrachium, in the city of Dyrrachium, in the city of Dyrrachium, in the city of Dyrrachium, in the city of Dyrrachium, in the city of Dyrrachium, in the city of Dyrrachium, in the city of Dyrrachium, in the city of Dyrrachium, in the
# ❌
# ================================================================================
# Question 27/100
# Q: What is the expression used to denote a worst case complexity as expressed by time taken?
# A: O(n2)
# ?: The time taken for sorting a list of integers is O(n log n)
# ❌
# ================================================================================
# Question 28/100
# Q: How would the capabilities approach achieve it's goal?
# A: through increasing functionings
# ?: Capabilities are the means by which people achieve their goals. They are the means by which people achieve their goals. Capabilities are the means by which people achieve their goals. Capabilities are the means by which people achieve their goals. Capabilities are the means by which people achieve their goals. Capabilities are the means by which people achieve their goals. Capabilities are the means by which people achieve their goals. Capabilities are the means by which people achieve their goals. Capabilities are the means by which people achieve their goals. Capabilities are the means by which people achieve their goals. Capabilities are the means by which people achieve
# ❌
# ================================================================================
# Question 29/100
# Q: Within what variable is L constrained according to the space hierarchy theorem?
# A: PSPACE
# ?: The space hierarchy theorem states that the space hierarchy theorem is true for all sets of variables
# ❌
# ================================================================================
# Question 30/100
# Q: What are the "Big Five" animals in Kenya?
# A: lion, leopard, buffalo, rhinoceros, and elephant
# ?: The lion, leopard, buffalo, rhinoceros, and elephant
# ❌
# ================================================================================
# Question 31/100
# Q: What is another way of referring to stators?
# A: static discs
# ?: The term stators is used to refer to the shafts of a turbine. The shafts are connected to the rotor shaft by a shaft that is rotated by a gearbox. The shafts are connected to the rotor shaft by a gearbox. The shafts are connected to the rotor shaft by a gearbox. The shafts are connected to the rotor shaft by a gearbox. The shafts are connected to the rotor shaft by a gearbox. The shafts are connected to the rotor shaft by a gearbox. The shafts are connected to the rotor shaft by a gearbox. The shafts are connected to the rotor
# ❌
# ================================================================================
# Question 32/100
# Q: When was the new two-year affiliate agreement approved?
# A: 2002
# ?: The new agreement was approved by the FCC on June 12, 2012
# ❌
# ================================================================================
# Question 33/100
# Q: What type of materials inside the cabin were removed to help prevent more fire hazards in the future?
# A: flammable cabin and space suit materials
# ?: The Block II spacecraft was designed to be a safe, reliable, and efficient spacecraft. The Block II spacecraft was designed to be a safe, reliable, and efficient spacecraft. The Block II spacecraft was designed to be a safe, reliable, and efficient spacecraft. The Block II spacecraft was designed to be a safe, reliable, and efficient spacecraft. The Block II spacecraft was designed to be a safe, reliable, and efficient spacecraft. The Block II spacecraft was designed to be a safe, reliable, and efficient spacecraft. The Block II spacecraft was designed to be a safe, reliable, and efficient spacecraft. The Block II spacecraft was designed to be a
# ❌
# ================================================================================
# Question 34/100
# Q: How many nations contain "Amazonas" in their names?
# A: States or departments in four nations contain "Amazonas" in their names.
# ?: The Amazon is a name that has been used since the early 19th century. The name is derived from the Amazon River, which flows through the Amazon Basin, and is a name used by the Brazilian government to designate the Amazonian rainforest. The Amazon River is the largest river in the world, and is the largest river in the world. The Amazon is the largest river in the world, and is the largest river in the world. The Amazon is the largest river in the world, and is the largest river in the world. The Amazon is the largest river in the world, and is the largest river in the world. The Amazon
# ❌
# ================================================================================
# Question 35/100
# Q: What was Tesla's position with Westinghouse?
# A: consultant
# ?: Westinghouse was a major player in the electrical industry, and Tesla was a major player in the electrical industry
# ❌
# ================================================================================
# Question 36/100
# Q: What year were the first Doctor Who stories available on CD?
# A: 1999
# ?: The first Doctor Who stories were published in the early 1990s
# ❌
# ================================================================================
# Question 37/100
# Q: What is the term for a task that generally lends itself to being solved by a computer?
# A: computational problems
# ?: A task is a task that is in principle amenable to being solved by a computer
# ❌
# ================================================================================
# Question 38/100
# Q: What was happening to subscriber numbers in other areas of europe?
# A: flattened
# ?: The number of subscribers in the UK was growing, but the number of subscribers in the rest of Europe was declining
# ❌
# ================================================================================
# Question 39/100
# Q: Dutch architect Janjaap Ruijssenaars's performative architecture 3D-printed building is scheduled to be built when?
# A: Working versions of 3D-printing building technology are already printing
# ?: In 2014, the Dutch architect Janjaap Ruijssenaars's performative architecture 3D-printing building is scheduled to be built in 2014
# ❌
# ================================================================================
# Question 40/100
# Q: When was the most recent Super Bowl hosted in the South Florida/Miami area?
# A: 2010
# ?: The Super Bowl was held in Miami in the summer of 2012
# ❌
# ================================================================================
# Writing evalMamba130M_Few_shot.json
# Question 41/100
# Q: The atomic number of the periodic table for oxygen?
# A: 8
# ?: The atomic number of oxygen is 8
# ❌
# ================================================================================
# Question 42/100
# Q: How were enemy prisoners used tactically by Mongol armies?
# A: driving them in front of the army
# ?: The Mongols used the prisoners as a means of controlling the enemy's forces. The Mongols used the prisoners as a means of controlling the enemy's forces. The Mongols used the prisoners as a means of controlling the enemy's forces
# ❌
# ================================================================================
# Question 43/100
# Q: What is the CJEU's duty?
# A: ensure that in the interpretation and application of the Treaties the law is observed
# ?: The CJEU is the highest court in the European Union, and it has the power to interpret treaties. It is also the highest court in the European Union, and it has the power to interpret treaties. It is also the highest court in the European Union, and it has the power to interpret treaties. It is also the highest court in the European Union, and it has the ability to interpret treaties
# ❌
# ================================================================================
# Question 44/100
# Q: Who was an important figure in the twentieth-century Islamic revival in India?
# A: Sayyid Abul Ala Maududi
# ?: The first major revival of Islam in India was in the early twentieth century, when the Indian National Congress was formed. The Congress was founded in the wake of the Indian independence movement, and was the first major political party to be formed in India. The Congress was the first major political party to be formed in India, and was the first major political party to be founded in the country. The Congress was the first major political party to be formed in India, and was the first major political party to be founded in the country
# ❌
# ================================================================================
# Question 45/100
# Q: When did the ban on cigarette advertising take effect for television networks?
# A: January 2, 1971
# ?: The ban was effective on January 2, 1972, and was repealed on January 2, 1973
# ❌
# ================================================================================
# Question 46/100
# Q: In what form is oxygen transported in smaller containers?
# A: compressed gas
# ?: The oxygen is transported in small containers, which are usually made of plastic or glass. The oxygen is stored in a special container, which is usually made of glass or plastic. The oxygen is stored in a special container, which is usually made of glass or plastic. The oxygen is stored in a special container, which is usually made of glass or plastic. The oxygen is stored in a special container, which is usually made of glass or plastic. The oxygen is stored in a special container, which is usually made of glass or plastic. The oxygen is stored in a special container, which is usually made of glass or plastic. The oxygen is
# ❌
# ================================================================================
# Question 47/100
# Q: When rich countries trade with poor countries, whose wages increase?
# A: workers in the poor countries
# ?: The United States and Canada have a trade agreement with Mexico, which is the largest trade agreement in the world. The United States and Mexico have a trade agreement with Canada, which is the largest trade agreement in the world. The United States and Canada have a trade agreement with Mexico, which is the largest trade agreement in the world. The United States and Canada have a trade agreement with Mexico, which is the largest trade agreement in the world. The United States and Canada have a trade agreement with Mexico, which is the largest trade agreement in the world
# ❌
# ================================================================================
# Question 48/100
# Q: Who led the Science and Environmental Policy Project?
# A: Fred Singer
# ?: The Science and Environmental Policy Project was founded in the late 1980s by the American Institute of Physics, the American Association for the Advancement of Science, and the American Association for the Advancement of Science. The project was funded by the National Science Foundation, the National Science Foundation, and the National Institutes of Health
# ❌
# ================================================================================
# Question 49/100
# Q: In what year did the NFL switch to a 16-game regular season?
# A: 1978
# ?: The NFL began playing a 16-game regular season in 1978, the first time since the NFL began playing a 16-game regular season in the 1950s. The NFL began playing a 16-game regular season in 1978, the first time since the 1950s. The NFL began playing a 16-game regular season in 1978, the first time since the 1950s. The NFL began playing a 16-game regular season in 1978, the first time since the 1950s
# ❌
# ================================================================================
# Question 50/100
# Q: What does computational complexity theory most specifically seek to answer?
# A: computational problems
# ?: Computational complexity theory is a branch of mathematics that deals with the problem of determining the complexity of a problem. It is a branch of mathematics that deals with the problem of determining the complexity of a problem
# ❌
# ================================================================================
# Question 51/100
# Q: What was the final score of Super Bowl 50?
# A: 24–10
# ?: The final score of Super Bowl 50 was 49–49
# ❌
# ================================================================================
# Question 52/100
# Q: What did Luther call the mass instead of sacrifice?
# A: a gift
# ?: The Mass
# ❌
# ================================================================================
# Question 53/100
# Q: What did Queen Elizabeth II open in Newcastle in 1981?
# A: A bridge
# ?: The Queen Elizabeth II Memorial, a memorial to the Queen's Royal Navy, was opened in 1981
# ❌
# ================================================================================
# Question 54/100
# Q: What kind of disorders are the result of an overactive immune response?
# A: autoimmune disorders
# ?: The immune system is a complex system, and it is not a simple one. The immune system is a complex system, and it is not a simple one. The immune system is a complex system, and it is not a simple one. The immune system is a complex system, and it is not a simple one
# ❌
# ================================================================================
# Question 55/100
# Q: Where hotel did the Panthers stay at?
# A: San Jose Marriott.
# ?: The San Jose Marriott was a hotel in the San Jose area.
# ❌
# ================================================================================
# Question 56/100
# Q: Why did Westinghouse not secure a patent for a similar motor?
# A: decided Tesla's patent would probably control the market
# ?: Westinghouse was not a patent-holder, but it was a company that had a patent on a similar motor
# ❌
# ================================================================================
# Question 57/100
# Q: What words to they think are linked to the work Kenya?
# A: Kirinyaga, Kirenyaa and Kiinyaa
# ?: The words "Kenya" and "Kenya" are the two most common words in the English language. The words "Kenya" and "Kenya" are also used in the English language
# ❌
# ================================================================================
# Question 58/100
# Q: When was the first known historical reference to immunity?
# A: Athens in 430 BC
# ?: In the year of the French Revolution, 1789
# ❌
# ================================================================================
# Question 59/100
# Q: What was the name of the Mongol Empire's legal code?
# A: Yassa
# ?: The Mongol Code of Laws was a code of law that was adopted by the Mongol Empire in the early 13th century. The Mongol Code of Laws was a code of laws that was adopted by the Mongol Empire in the early 13th century. The Mongol Code of Laws was a code of laws that was adopted by the Mongol Empire in the early 13th century. The Mongol Code of Laws was a code of laws that was adopted by the Mongol Empire in the early 13th century. The Mongol Code of Laws was a code of laws that was adopted by the Mongol Empire in the early 13th
# ❌
# ================================================================================
# Question 60/100
# Q: When had the Six Ministries existed?
# A: since the Sui and Tang dynasties
# ?: The Six Ministries were established in the Yuan period in the early 13th century. The first six ministries were established in the Yuan period in the late 13th century. The first six ministries were established in the Yuan period in the late 13th century. The first six ministries were established in the Yuan period in the late 13th century. The first six ministries were established in the Yuan period in the late 13th century. The first six ministries were established in the Yuan period in the late 13th century. The first six ministries were established in the Yuan period in the late 13th century. The first six
# ❌
# ================================================================================
# Writing evalMamba130M_Few_shot.json
# Question 61/100
# Q: How to Baptized Members become Professing Members?
# A: confirmation and sometimes the profession of faith
# ?: Baptized Members are those who have been baptized as an infant or adult, but who have not subsequently professed their own faith. They may be a member of a denomination or a member of a denomination
# ❌
# ================================================================================
# Question 62/100
# Q: After asking if the books were his, what else did Eck ask Luther?
# A: stood by their contents
# ?: He said that they were his, and that he had written them
# ❌
# ================================================================================
# Question 63/100
# Q: When did the Pope warned Luther of excommunication?
# A: 15 June 1520
# ?: On the 15th of March 1521, Luther wrote to the Pope, "I have been informed that the Pope has sent you a letter of excommunication, which I have not yet received." Luther's letter was sent to the Pope on the day of the pope's coronation, on the day of the coronation of the Pope. Luther's letter was not published until 1524, when it was published in the New Testament
# ❌
# ================================================================================
# Question 64/100
# Q: When large groups of people all boycott a system or don't pay taxes it can be considered?
# A: coercive
# ?: The term "bargaining" is used to describe the practice of refusing to pay taxes
# ❌
# ================================================================================
# Question 65/100
# Q: What ABC action series went up against NBC's variety shows in Fall 1957?
# A: Zorro
# ?: The series The Adventures of Tintin, which aired in the fall of 1957, was a series of short films that were shown on ABC's network. The series was a continuation of the series The Adventures of Tintin, which had been shown on ABC since the late 1940s. The series was a hit, and ABC's network was able to get the series on the air in the fall of 1957
# ❌
# ================================================================================
# Question 66/100
# Q: What was the significance of victory at Forth Niagara for British?
# A: cut off the French frontier forts further to the west and south
# ?: The victory was a major victory for the British, as it was the first time that the British had won a major battle in the American War of Independence. The British had won the Battle of the Nile in 1812, and the Battle of the Nile in 1815. The victory at Forth Niagara was the first major victory for the British in the American War of Independence
# ❌
# ================================================================================
# Question 67/100
# Q: What is the Latin name for Black Death?
# A: atra mors
# ?: The Latin name for Black Death is Black Death
# ❌
# ================================================================================
# Question 68/100
# Q: What are the phagocytes that are located in tissues in contact with the external environment called?
# A: Dendritic cells
# ?: The phagocytes are the cells that are located in the tissues that are in contact with the external environment. They are the cells that are located in the tissues that are in contact with the external environment. They are the cells that are located in the tissues that are in contact with the external environment
# ❌
# ================================================================================
# Question 69/100
# Q: What profession was Nathan Alterman?
# A: poet
# ?: He was a painter
# ❌
# ================================================================================
# Question 70/100
# Q: What type of vote must the Parliament have to either block or suggest changes to the Commission's proposals?
# A: a majority
# ?: The Parliament must vote by a majority of all MEPs to block or suggest changes to the Commission's proposals. The Commission must vote by qualified majority to block or suggest changes to the Commission's proposals. The Parliament must vote by a majority of all MEPs to approve or suggest changes to the Commission's proposals. The Parliament must vote by qualified majority to block or suggest changes to the Commission's proposals. The Parliament must vote by a majority of all MEPs to block or suggest changes to the Commission's proposals. The Parliament must vote by a majority of all MEPs to approve or suggest changes to the Commission's proposals. The Parliament must vote
# ❌
# ================================================================================
# Question 71/100
# Q: What percentage of money raised was earmarked for causes in the San Francisco area?
# A: 25 percent
# ?: The committee has raised $1.5 million for the San Francisco Bay Area Children's Cancer Fund, which is a non-profit organization dedicated to helping children in the Bay Area
# ❌
# ================================================================================
# Question 72/100
# Q: In which year was the Musical Instruments gallery closed?
# A: 2010
# ?: The museum closed on the first day of the year, on the first day of the year, on the first day of the month, and on the first day of the year
# ❌
# ================================================================================
# Question 73/100
# Q: What scientific field's theory has received contributions from the steam engine?
# A: thermodynamic
# ?: The steam engine was developed by the French engineer Pierre-Joseph-Joseph Dufour in the late 1700s. Dufour's work was based on the theory of the steam engine, which was developed by the French engineer Pierre-Joseph-Joseph Dufour in the late 1700s. Dufour's theory was based on the idea that the steam engine was a machine that could be used to generate electricity. The steam engine was developed by Dufour in the late 1700s. Dufour's theory was based on the idea that the steam engine was a machine that could generate electricity. The steam engine was
# ❌
# ================================================================================
# Question 74/100
# Q: What type of organization would need large quantities of pure oxygen?
# A: hospitals
# ?: The United States, Canada, and Australia are the only countries that have a national oxygen supply system. The United States has a national oxygen supply system that is based on the use of a mixture of oxygen and nitrogen. The United States has a national oxygen supply system that is based on the use of a mixture of oxygen and nitrogen. The United States has a national oxygen supply system that is based on the use of a mixture of oxygen and nitrogen. The United States has a national oxygen supply system that is based on the use of a mixture of oxygen and nitrogen. The United States has a national oxygen supply system that is based on the use of
# ❌
# ================================================================================
# Question 75/100
# Q: How much Saharan dust falls over the Amazon basin each year?
# A: 27.7 million tons
# ?: The Saharan dust is transported by wind, and is transported by the wind. The amount of dust is measured by the amount of dust that is blown out of the Sahara each year
# ❌
# ================================================================================
# Question 76/100
# Q: How long after a banquet with Tugh Temur did Kusala die?
# A: four days
# ?: Kusala died on the third day of the banquet
# ❌
# ================================================================================
# Question 77/100
# Q: What type of people were being brought back to the way of truth?
# A: misguided
# ?: The people who were brought back were the people who had been brought back to the way of truth
# ❌
# ================================================================================
# Question 78/100
# Q: What did the Greek root pharmakos imply?
# A: sorcery or even poison
# ?: The Greek word pharmakos (φάρμακος) derives from its root word pharma which means "drug", "treatment", "treatment", "medicine", "treatment", "treatment", "treatment", "treatment", "treatment", "treatment", "treatment", "treatment", "treatment", "treatment", "treatment", "treatment", "treatment", "treatment", "treatment", "treatment", "treatment", "treatment", "treatment", "treatment", "treatment", "treatment", "treatment", "treatment", "treatment", "treatment", "treatment", "treatment", "treatment", "treatment", "
# ❌
# ================================================================================
# Question 79/100
# Q: What was Fort Caroline renamed to after the Spanish attack?
# A: San Mateo
# ?: Fort Caroline was renamed Fort St. Augustine after the Spanish attack
# ❌
# ================================================================================
# Question 80/100
# Q: Which territory did Jochi try to protect that may have led to a dispute with his brothers?
# A: Urgench
# ?: The territory of the French province of Normandy, which was part of the French Empire
# ❌
# ================================================================================
# Writing evalMamba130M_Few_shot.json
# Question 81/100
# Q: What ranking does the Super Bowl 50 halftime show have on the list of most watched TV broadcasts?
# A: third
# ?: The Super Bowl 50 halftime show is ranked #1 in the U.S. and #1 in the world
# ❌
# ================================================================================
# Question 82/100
# Q: What music did the fourth soundtrack feature?
# A: music from the 2008–2010 specials
# ?: The soundtrack for Series 5 featured music from the third and fourth series, the first two featured songs from the third and fourth series respectively. The soundtrack for Series 6 was released on 4 October 2010
# ❌
# ================================================================================
# Question 83/100
# Q: What administration did Ludwig Mies van der Rohe designa buiding?
# A: School of Social Service Administration
# ?: Ludwig Mies van der Rohe was a German-born architect who designed the first modern buildings in the United States. He was born in 1877 in the city of Münster, Germany, and was the son of a wealthy family. He was educated at the University of Münster and the University of Berlin, where he graduated in 1912. He was a member of the Prussian Academy of Sciences and was a member of the Prussian Academy of Arts and Sciences. He was a member of the Prussian Academy of Sciences and the Prussian Academy of Arts and Sciences. He was a member of the Prussian Academy of Sciences
# ❌
# ================================================================================
# Question 84/100
# Q: What was Manning's passer rating for the 2015 season?
# A: 67.9
# ?: Manning's passer rating was 95.0, which was the highest of any quarterback in the NFL
# ❌
# ================================================================================
# Question 85/100
# Q: Issues dealt with at Westminster are not ones who is able to deal with?
# A: Scottish Parliament
# ?: The Scottish Parliament is not able to deal with issues that are not dealt with at Westminster
# ❌
# ================================================================================
# Question 86/100
# Q: What was the wedding date?
# A: 12 May 1191
# ?: The wedding was held on the day of the coronation of King John of Cyprus
# ❌
# ================================================================================
# Question 87/100
# Q: What did the development of this fertile soil provide in hostile environment?
# A: agriculture and silviculture
# ?: The soil was fertile, but it was not a perfect soil. The soil was not perfectly fertile, but it was fertile enough to support the growth of plants and animals. The soil was also fertile enough to support the growth of plants and animals. The soil was also fertile enough to support the growth of plants and animals
# ❌
# ================================================================================
# Question 88/100
# Q: Who did the North declare for during the English civil war?
# A: the King
# ?: The Scots
# ❌
# ================================================================================
# Question 89/100
# Q: Which country does the Rhine encounter it's main tributaries?
# A: Germany
# ?: The Rhine drains to the Rhine via the Moselle; it also drains to the Vosges via the Moselle. The main tributaries of the Rhine are the Rhine, the Rhine-Main, the Rhine-Main, the Rhine-Main, the Rhine-Main, the Rhine-Main, the Rhine-Main, the Rhine-Main, the Rhine-Main, the Rhine-Main, the Rhine-Main, the Rhine-Main, the Rhine-Main, the Rhine-Main, the Rhine-Main, the Rhine
# ❌
# ================================================================================
# Question 90/100
# Q: What French animation studio did ABC purchase in 1993?
# A: DIC Entertainment
# ?: DIC Entertainment
# ✅
# ================================================================================
# Question 91/100
# Q: What rive joins the Rhine in Duisburg?
# A: Ruhr
# ?: The Rhine is a river of the Rhine-Ruhr-region, which is the largest river in the world. It is the largest river in the world, and the largest river in the world. It is the largest river in the world, and the largest river in the world. It is the largest river in the world, and the largest river in the world. It is the largest river in the world, and the largest river in the world. It is the largest river in the world, and the largest river in the world. It is the largest river in the world, and the largest river in the world. It
# ❌
# ================================================================================
# Question 92/100
# Q: Which animal's venom did Pierre-Louis Moreau de Maupertuis work with?
# A: scorpion
# ?: The venom of the venomous snake, the snake venom gland, is the most important source of venom in the world. It is the most potent of all venomous snakes, and it is the most dangerous. It is the most dangerous of all snakes, and it is the most dangerous of all snakes. It is the most dangerous of all snakes, and it is the most dangerous of all snakes. It is the most dangerous of all snakes, and it is the most dangerous of all snakes. It is the most dangerous of all snakes, and it is the most dangerous of all snakes. It is the most dangerous of all snakes, and
# ❌
# ================================================================================
# Question 93/100
# Q: In the capabilities approach, grow and income are considered a means to an end rather than what?
# A: the end itself
# ?: The capabilities approach is a form of economic growth and income. It is a form of economic growth and income that is not a means to an end. It is a form of economic growth and income that is not a means to an end
# ❌
# ================================================================================
# Question 94/100
# Q: Where are Jersey and Guernsey
# A: Channel Islands
# ?: Jersey and Guernsey
# ❌
# ================================================================================
# Question 95/100
# Q: What was the boat called?
# A: teleautomaton
# ?: The "Teleautomaton" was a small boat with a small sail, and it was built in the early 1900s. It was a small boat with a small sail, and it was used to sail around the world
# ❌
# ================================================================================
# Question 96/100
# Q: What did the SNP publicly opine about the oil revenues?
# A: not benefitting Scotland as much as they should
# ?: The SNP's position was that the revenues were not sufficient to fund the oil industry. The SNP's position was that the oil revenues were sufficient to fund the oil industry
# ❌
# ================================================================================
# Question 97/100
# Q: How many days after Gagarin's flight did the US House Committee on Science and Astronautics meet?
# A: one day
# ?: one day
# ✅
# ================================================================================
# Question 98/100
# Q: How can function problems typically be restated?
# A: decision problems
# ?: The function problem is a problem in the sense that it is a problem in the sense that it is a problem in the sense that it is a problem in the sense that it is a problem in the sense that it is a problem in the sense that it is a problem in the sense that it is a problem in the sense that it is a problem in the sense that it is a problem in the sense that it is a problem in the sense that it is a problem in the sense that it is a problem in the sense that it is a problem in the sense that it is a problem in the sense that it is a problem in the
# ❌
# ================================================================================
# Question 99/100
# Q: What does Fortiter Defendit Triumphans mean?
# A: Triumphing by a brave defence
# ?: Fortiter Defendit means to protect the town from the enemy
# ❌
# ================================================================================
# Question 100/100
# Q: Recent studies believe  that ctenophores are the sister lineage to what?
# A: all other animals
# ?: Recent studies have shown that ctenophores are the sister lineage to all other animal phyla. This is a result of the fact that ctenophores are the sister to all other animal phyla
# ❌
# ================================================================================
# Writing evalMamba130M_Few_shot.json
# Accuracy: 2.0% -- 2 correct and 98 incorrect
# Number of tokens generated: 53223 -- Time: 21.026938438415527 -- Tokens-Per-Sec: 2531.181615235213

# %%
tokenizer130m = None
model130m = None

gc.collect()
# Out:
# 475

# %% [markdown]
# ## 790M model

# %%
tokenizer790m = AutoTokenizer.from_pretrained("state-spaces/mamba-790m-hf", padding_side='left')
model790m = MambaForCausalLM.from_pretrained("state-spaces/mamba-790m-hf")
tokenizer790m.eos_token = "<|endoftext|>"
tokenizer790m.pad_token = tokenizer790m.eos_token
# Out:
# tokenizer_config.json:   0%|          | 0.00/4.79k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# config.json:   0%|          | 0.00/878 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.17G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/137 [00:00<?, ?B/s]

# %%
eval(data[:100], model790m, tokenizer790m, "evalMamba790M.json", few_shot=False, batch_size=32)
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Question 1/100
# Q: How many yards did the Panthers get for the division championshipt game?
# A: 487
# ?: 31
# ❌
# ================================================================================
# Question 2/100
# Q: What caused Jacksonville's tourism to become less desirable at the latter half of the 19th century?
# A: yellow fever outbreaks
# ?: The city's population declined from about 100,000 in 1900 to about 50,000 in 1920. The city's economy was based on the railroad and the city's growth was limited by the railroad's expansion. The city's population declined from about 100,000 in 1900 to about 50,000 in 1920. The city's economy was based on the railroad and the city's growth was limited by the railroad's expansion. The city's population declined from about 100,000 in 1900 to about 50,000 in 1920. The city's economy was based on the railroad and the city's growth was limited by the railroad's expansion. The city
# ❌
# ================================================================================
# Question 3/100
# Q: What are pharmacists in the United Kingdom being increasingly paid for?
# A: medicine use reviews
# ?: The United Kingdom has a National Health Service (NHS) and the NHS is funded by the government. The NHS is responsible for providing health care to the people of the United Kingdom. The NHS is funded by the government and the government is responsible for the running of the NHS. The government is responsible for the running of the NHS. The government is responsible for the running of the NHS. The government is responsible for the running of the NHS. The government is responsible for the running of the NHS. The government is responsible for the running of the NHS. The government is responsible for the running of the NHS. The government is responsible for the
# ❌
# ================================================================================
# Question 4/100
# Q: Geoglyphs dating to what period were found in deforested land along the Amazon River?
# A: AD 0–1250
# ?: Geoglyphs dating to what period were found in deforested land along the Amazon River?
# ❌
# ================================================================================
# Question 5/100
# Q: Who does a gender pay gap tend to favor?
# A: males in the labor market
# ?: Women
# ❌
# ================================================================================
# Question 6/100
# Q: What is the annual construction industry revenue in 2014?
# A: $960 billion
# ?: $960 billion
# ✅
# ================================================================================
# Question 7/100
# Q: Which sculpture by Michelangelo has a full-size replica in the Cast Courts?
# A: David
# ?: The David
# ❌
# ================================================================================
# Question 8/100
# Q: Richard Allen and Absalom Jones were licensed by St. George's Church in what year?
# A: 1784
# ?: 1784
# ✅
# ================================================================================
# Question 9/100
# Q: Where does the Rhine end?
# A: Hoek van Holland
# ?: The Rhine ends at the confluence of the Rhine and the Rhine-Meuse Canal in the town of Hoek van Holland
# ❌
# ================================================================================
# Question 10/100
# Q: The V&A has the world's most comprehensive collection of sculptures from which period?
# A: post-classical European
# ?: The V&A has the world's most comprehensive collection of sculptures from which period?
# ❌
# ================================================================================
# Question 11/100
# Q: Which country rationed gasoline and heating gas?
# A: Sweden
# ?: The Netherlands
# ❌
# ================================================================================
# Question 12/100
# Q: The United States is divided into how many jurisdictions?
# A: five
# ?: There are five jurisdictions: Northeastern, Southeastern, North Central, South Central and Western. Outside the United States the church is divided into seven central conferences: Africa, Congo, West Africa, Central & Southern Europe, Germany, Northern Europe and the Philippines. The main purpose of the jurisdictions and central conferences is to elect and appoint bishops, the chief administrators of the church. Bishops thus elected serve Episcopal Areas, which consist of one or more Annual Conferences
# ❌
# ================================================================================
# Question 13/100
# Q: What is an example of a machine model that deviates from a generally accepted multi-tape Turing machine?
# A: random access machines
# ?: The most common example is the one-tape Turing machine. This machine is deterministic and has a single tape. The machine is in the state of the tape at the beginning of the computation. The machine is in the state of the tape at the beginning of the computation. The machine is in the state of the tape at the beginning of the computation. The machine is in the state of the tape at the beginning of the computation. The machine is in the state of the tape at the beginning of the computation. The machine is in the state of the tape at the beginning of the computation. The machine is in the state of the
# ❌
# ================================================================================
# Question 14/100
# Q: What company developed the most successful steam engine indicator?
# A: Charles Porter
# ?: The most successful steam engine indicator was developed by Charles Richard and exhibited at London Exhibition in 1862. The steam engine indicator traces on paper the pressure in the cylinder throughout the cycle, which can be used to spot various problems and calculate developed horsepower. It can also be used on internal combustion engines. See image of indicator diagram below (in Types of motor units section)
# ❌
# ================================================================================
# Question 15/100
# Q: Who dates rocks, precisely, within the stratigraphic section?
# A: Geochronologists
# ?: The geochronologists
# ❌
# ================================================================================
# Question 16/100
# Q: Who formulated the idea of clonal selection theory of immunity?
# A: Frank Burnet
# ?: Frank Burnet
# ✅
# ================================================================================
# Question 17/100
# Q: What is the second most abundant element?
# A: helium
# ?: Oxygen
# ❌
# ================================================================================
# Question 18/100
# Q: what was invented in 1880 that revolutionized warfare?
# A: the machine gun
# ?: the machine gun
# ✅
# ================================================================================
# Question 19/100
# Q: When did Watt finish the development of his improvements to Newcomen's engine?
# A: 1775
# ?: Watt's improvements were not completed until 1775
# ❌
# ================================================================================
# Question 20/100
# Q: What is the largest item from Italy that is part of the sculpture collection?
# A: Chancel Chapel
# ?: The largest item from Italy is the Chancel Chapel from Santa Chiara Florence dated 1493–1500, designed by Giuliano da Sangallo it is 11.1 metres in height by 5.4 metres square, it includes a grand sculpted tabernacle by Antonio Rossellino and coloured terracotta decoration
# ❌
# ================================================================================
# Writing evalMamba790M.json
# Question 21/100
# Q: Antibodies are transferred to the gut of the infant through what means?
# A: Breast milk or colostrum
# ?: The fetus does not make any memory cells or antibodies—it only borrows them. This passive immunity can also be transferred artificially from one individual to another via antibody-rich serum
# ❌
# ================================================================================
# Question 22/100
# Q: Which century was there a program to straighten the Rhine?
# A: 19th Century
# ?: The program was started in 1853
# ❌
# ================================================================================
# Question 23/100
# Q: Where was the first horse racetrack located?
# A: Pole Mokotowskie
# ?: The first horse racetrack in Warsaw was located in the Praga district. It was built in 1869, and it was the first in the city. The track was located in the area of the present-day Praga Park
# ❌
# ================================================================================
# Question 24/100
# Q: What did the Islamic State proclaim itself in 2014?
# A: a caliphate
# ?: The Islamic State proclaimed itself a caliphate, with religious, political and military authority over all Muslims worldwide. As of March 2015, it had control over territory occupied by ten million people in Iraq and Syria, and has nominal control over small areas of Libya, Nigeria and Afghanistan. (While a self-described state, it lacks international recognition.) The group also operates or has affiliates in other parts of the world, including North Africa and South Asia
# ❌
# ================================================================================
# Question 25/100
# Q: What plants don't need light to make chloroplasts?
# A: Gymnosperms
# ?: None
# ❌
# ================================================================================
# Question 26/100
# Q: Where was Dyrrachium located?
# A: the Adriatic
# ?: Dyrrachium was located on the coast of the Adriatic Sea, in the region of the modern-day city of Split
# ❌
# ================================================================================
# Question 27/100
# Q: What is the expression used to denote a worst case complexity as expressed by time taken?
# A: O(n2)
# ?: The expression is O(n log n)
# ❌
# ================================================================================
# Question 28/100
# Q: How would the capabilities approach achieve it's goal?
# A: through increasing functionings
# ?: It would increase the number of people who are able to pursue their valued functions
# ❌
# ================================================================================
# Question 29/100
# Q: Within what variable is L constrained according to the space hierarchy theorem?
# A: PSPACE
# ?: L is constrained according to the space hierarchy theorem
# ❌
# ================================================================================
# Question 30/100
# Q: What are the "Big Five" animals in Kenya?
# A: lion, leopard, buffalo, rhinoceros, and elephant
# ?: The "Big Five" animals of Kenya are the lion, leopard, buffalo, rhinoceros and elephant
# ❌
# ================================================================================
# Question 31/100
# Q: What is another way of referring to stators?
# A: static discs
# ?: Stators are the rotating parts of a steam turbine
# ❌
# ================================================================================
# Question 32/100
# Q: When was the new two-year affiliate agreement approved?
# A: 2002
# ?: The agreement was approved in 2002
# ❌
# ================================================================================
# Question 33/100
# Q: What type of materials inside the cabin were removed to help prevent more fire hazards in the future?
# A: flammable cabin and space suit materials
# ?: The cabin was made of a lightweight, fire-resistant material, and the cabin was equipped with a fire-resistant door
# ❌
# ================================================================================
# Question 34/100
# Q: How many nations contain "Amazonas" in their names?
# A: States or departments in four nations contain "Amazonas" in their names.
# ?: Brazil, Colombia, Ecuador, French Guiana, Guyana, Suriname, Venezuela, and Bolivia.
# ❌
# ================================================================================
# Question 35/100
# Q: What was Tesla's position with Westinghouse?
# A: consultant
# ?: Tesla was a consultant to Westinghouse Electric & Manufacturing Company. He was paid $2,500 per month for his services
# ❌
# ================================================================================
# Question 36/100
# Q: What year were the first Doctor Who stories available on CD?
# A: 1999
# ?: The first Doctor Who story available on CD was the first story of the Fifth Doctor's adventures, The Daleks' Master Plan, which was released in 1979
# ❌
# ================================================================================
# Question 37/100
# Q: What is the term for a task that generally lends itself to being solved by a computer?
# A: computational problems
# ?: Computational complexity theory
# ❌
# ================================================================================
# Question 38/100
# Q: What was happening to subscriber numbers in other areas of europe?
# A: flattened
# ?: In the UK, the number of subscribers had grown by more than 2 million in the last year, to reach 25m. In Germany, the number of subscribers had grown by more than 1 million, to reach 16m. In France, the number of subscribers had grown by more than 1 million, to reach 14m. In Spain, the number of subscribers had grown by more than 1 million, to reach 13m. In Italy, the number of subscribers had grown by more than 1 million, to reach 12m. In the Netherlands, the number of subscribers had grown by more than 1 million, to reach 11m. In Belgium
# ❌
# ================================================================================
# Question 39/100
# Q: Dutch architect Janjaap Ruijssenaars's performative architecture 3D-printed building is scheduled to be built when?
# A: Working versions of 3D-printing building technology are already printing
# ?: Janjaap Ruijssenaars's performative architecture 3D-printed building is scheduled to be built when?
# ❌
# ================================================================================
# Question 40/100
# Q: When was the most recent Super Bowl hosted in the South Florida/Miami area?
# A: 2010
# ?: The most recent Super Bowl was in 2010, hosted by the San Francisco 49ers
# ❌
# ================================================================================
# Writing evalMamba790M.json
# Question 41/100
# Q: The atomic number of the periodic table for oxygen?
# A: 8
# ?: 8
# ✅
# ================================================================================
# Question 42/100
# Q: How were enemy prisoners used tactically by Mongol armies?
# A: driving them in front of the army
# ?: The Mongol army was also successful in siege warfare, cutting off resources for cities and towns by diverting certain rivers, taking enemy prisoners and driving them in front of the army, and adopting new ideas, techniques and tools from the people they conquered, particularly in employing Muslim and Chinese siege engines and engineers to aid the Mongol cavalry in capturing cities. Another standard tactic of the Mongol military was the commonly practiced feigned retreat to break enemy formations and to lure small enemy groups away from the larger group and defended position for ambush and counterattack
# ❌
# ================================================================================
# Question 43/100
# Q: What is the CJEU's duty?
# A: ensure that in the interpretation and application of the Treaties the law is observed
# ?: The CJEU's duty is to interpret the treaties and to apply the law
# ❌
# ================================================================================
# Question 44/100
# Q: Who was an important figure in the twentieth-century Islamic revival in India?
# A: Sayyid Abul Ala Maududi
# ?: Maududi was an important figure in the revival. He was a lawyer by profession, and a leading figure in the revival of the Islamic revival in India. He was a leading figure in the revival of the Islamic revival in India. He was a leading figure in the revival of the Islamic revival in India. He was a leading figure in the revival of the Islamic revival in India. He was a leading figure in the revival of the Islamic revival in India. He was a leading figure in the revival of the Islamic revival in India. He was a leading figure in the revival of the Islamic revival in India. He was a leading figure in
# ❌
# ================================================================================
# Question 45/100
# Q: When did the ban on cigarette advertising take effect for television networks?
# A: January 2, 1971
# ?: In April 1970, Congress passed the Public Health Cigarette Smoking Act which banned cigarette advertising from all television and radio networks, including ABC, when it took effect for television networks. Citing limited profitability of its cinemas, ABC Great States, the Central West division of ABC Theatres, was sold to Henry Plitt in 1974. On January 17, 1972, Elton Rule was named President and Chief Operating Officer of ABC a few months after Goldenson reduced his role in the company after suffering a heart attack
# ❌
# ================================================================================
# Question 46/100
# Q: In what form is oxygen transported in smaller containers?
# A: compressed gas
# ?: In liquid form, oxygen is transported in large cylinders
# ❌
# ================================================================================
# Question 47/100
# Q: When rich countries trade with poor countries, whose wages increase?
# A: workers in the poor countries
# ?: When rich countries trade with poor countries, the low-skilled workers in the rich countries may see reduced wages as a result of the competition, while low-skilled workers in the poor countries may see increased wages
# ❌
# ================================================================================
# Question 48/100
# Q: Who led the Science and Environmental Policy Project?
# A: Fred Singer
# ?: The project was led by the National Academy of Sciences, which is a non-profit organization
# ❌
# ================================================================================
# Question 49/100
# Q: In what year did the NFL switch to a 16-game regular season?
# A: 1978
# ?: In 1966, the NFL adopted a 16-game regular season. The NFL had been playing a 12-game regular season since the 1950 season
# ❌
# ================================================================================
# Question 50/100
# Q: What does computational complexity theory most specifically seek to answer?
# A: computational problems
# ?: It seeks to answer the question, "What is the best way to solve a particular problem?"
# ❌
# ================================================================================
# Question 51/100
# Q: What was the final score of Super Bowl 50?
# A: 24–10
# ?: 24–10
# ✅
# ================================================================================
# Question 52/100
# Q: What did Luther call the mass instead of sacrifice?
# A: a gift
# ?: The Mass is a sacrifice
# ❌
# ================================================================================
# Question 53/100
# Q: What did Queen Elizabeth II open in Newcastle in 1981?
# A: A bridge
# ?: The Tyne and Wear Metro
# ❌
# ================================================================================
# Question 54/100
# Q: What kind of disorders are the result of an overactive immune response?
# A: autoimmune disorders
# ?: Autoimmune disorders are a group of diseases that are caused by an overactive immune response. The immune system is a complex system that is composed of many different types of cells. The immune system is responsible for protecting the body from foreign invaders. The immune system is also responsible for eliminating self-reactive cells. The immune system is responsible for eliminating self-reactive cells. The immune system is responsible for eliminating self-reactive cells. The immune system is responsible for eliminating self-reactive cells. The immune system is responsible for eliminating self-reactive cells. The immune system is responsible for eliminating self-reactive cells. The immune system is responsible for
# ❌
# ================================================================================
# Question 55/100
# Q: Where hotel did the Panthers stay at?
# A: San Jose Marriott.
# ?: The Panthers stayed at the San Jose State practice facility and stayed at the Santa Clara Marriott.
# ❌
# ================================================================================
# Question 56/100
# Q: Why did Westinghouse not secure a patent for a similar motor?
# A: decided Tesla's patent would probably control the market
# ?: Westinghouse was not interested in the motor because it was not a new idea. Tesla's induction motor was a new idea, but Westinghouse was not interested in the motor because it was not a new idea. Tesla's induction motor was a new idea, but Westinghouse was not interested in the motor because it was not a new idea. Tesla's induction motor was a new idea, but Westinghouse was not interested in the motor because it was not a new idea. Tesla's induction motor was a new idea, but Westinghouse was not interested in the motor because it was not a new idea. Tesla's induction
# ❌
# ================================================================================
# Question 57/100
# Q: What words to they think are linked to the work Kenya?
# A: Kirinyaga, Kirenyaa and Kiinyaa
# ?: The words are:
# ❌
# ================================================================================
# Question 58/100
# Q: When was the first known historical reference to immunity?
# A: Athens in 430 BC
# ?: The earliest known reference to immunity was during the plague of Athens in 430 BC. Thucydides noted that people who had recovered from a previous bout of the disease could nurse the sick without contracting the illness a second time. In the 18th century, Pierre-Louis Moreau de Maupertuis made experiments with scorpion venom and observed that certain dogs and mice were immune to this venom. This and other observations of acquired immunity were later exploited by Louis Pasteur in his development of vaccination and his proposed germ theory of disease. Pasteur's theory was in direct opposition to contemporary theories of disease, such as the mi
# ❌
# ================================================================================
# Question 59/100
# Q: What was the name of the Mongol Empire's legal code?
# A: Yassa
# ?: The Mongol Empire was governed by a civil and military code, called the Yassa, created by Genghis Khan. The Mongol Empire did not emphasize the importance of ethnicity and race in the administrative realm, instead adopting an approach grounded in meritocracy. The exception was the role of Genghis Khan and his family. The Mongol Empire was one of the most ethnically and culturally diverse empires in history, as befitted its size. Many of the empire's nomadic inhabitants considered themselves Mongols in military and civilian life, including Mongols, Turks and others and included many diverse Khans of various ethnicities as part
# ❌
# ================================================================================
# Question 60/100
# Q: When had the Six Ministries existed?
# A: since the Sui and Tang dynasties
# ?: The Six Ministries were established in the Yuan dynasty. The first ministry was the Ministry of Justice, which was established in 1215. The second ministry was the Ministry of War, which was established in 1216. The third ministry was the Ministry of Finance, which was established in 1217. The fourth ministry was the Ministry of Education, which was established in 1218. The fifth ministry was the Ministry of Commerce, which was established in 1219. The sixth ministry was the Ministry of Culture, which was established in 1220
# ❌
# ================================================================================
# Writing evalMamba790M.json
# Question 61/100
# Q: How to Baptized Members become Professing Members?
# A: confirmation and sometimes the profession of faith
# ?: Baptized Members become Professing Members through confirmation and sometimes the profession of faith. Individuals who were not previously baptized are baptized as part of their profession of faith and thus become Professing Members in this manner. Individuals may also become a Professing Member through transfer from another Christian denomination
# ❌
# ================================================================================
# Question 62/100
# Q: After asking if the books were his, what else did Eck ask Luther?
# A: stood by their contents
# ?: Eck asked Luther if he had any other books besides the ones he had given him. Luther replied that he had a few more, but that he had not yet read them. Eck asked Luther if he had any other books besides the ones he had given him. Luther replied that he had a few more, but that he had not yet read them. Eck asked Luther if he had any other books besides the ones he had given him. Luther replied that he had a few more, but that he had not yet read them. Eck asked Luther if he had any other books besides the ones he had given him. Luther replied that he had a
# ❌
# ================================================================================
# Question 63/100
# Q: When did the Pope warned Luther of excommunication?
# A: 15 June 1520
# ?: The Pope warned Luther of excommunication on 3 January 1521
# ❌
# ================================================================================
# Question 64/100
# Q: When large groups of people all boycott a system or don't pay taxes it can be considered?
# A: coercive
# ?: Yes, it can be considered coercive
# ❌
# ================================================================================
# Question 65/100
# Q: What ABC action series went up against NBC's variety shows in Fall 1957?
# A: Zorro
# ?: The first of the action series to go up against NBC's variety shows was the ABC-produced The Adventures of Wild Bill Hickok, which debuted on October 1, 1957. The series was a remake of the original series, which had been a hit in the early 1950s. The series was a hit, and ABC decided to repeat the series in the fall of 1958. The series was a hit again in the fall of 1959, and ABC decided to repeat the series in the fall of 1960. The series was a hit again in the fall of 1961
# ❌
# ================================================================================
# Question 66/100
# Q: What was the significance of victory at Forth Niagara for British?
# A: cut off the French frontier forts further to the west and south
# ?: The victory at Forth Niagara was the first time that the British had successfully captured a French fortress in North America. The French had been defeated at the Battle of Sainte-Foy in 1759, but the British had been unable to take the fortress. The victory at Forth Niagara was the first time that the British had successfully captured a French fortress in North America. The French had been defeated at the Battle of Sainte-Foy in 1759, but the British had been unable to take the fortress. The victory at Forth Niagara was the first time that the British had successfully captured a French fortress
# ❌
# ================================================================================
# Question 67/100
# Q: What is the Latin name for Black Death?
# A: atra mors
# ?: Atra mors
# ✅
# ================================================================================
# Question 68/100
# Q: What are the phagocytes that are located in tissues in contact with the external environment called?
# A: Dendritic cells
# ?: Dendritic cells
# ✅
# ================================================================================
# Question 69/100
# Q: What profession was Nathan Alterman?
# A: poet
# ?: He was a writer
# ❌
# ================================================================================
# Question 70/100
# Q: What type of vote must the Parliament have to either block or suggest changes to the Commission's proposals?
# A: a majority
# ?: The Parliament must vote by qualified majority
# ❌
# ================================================================================
# Question 71/100
# Q: What percentage of money raised was earmarked for causes in the San Francisco area?
# A: 25 percent
# ?: The committee will allocate 25 percent of all money raised for philanthropic causes in the Bay Area
# ❌
# ================================================================================
# Question 72/100
# Q: In which year was the Musical Instruments gallery closed?
# A: 2010
# ?: In 2007
# ❌
# ================================================================================
# Question 73/100
# Q: What scientific field's theory has received contributions from the steam engine?
# A: thermodynamic
# ?: The steam engine has been the main source of scientific contributions to the theory of heat and steam
# ❌
# ================================================================================
# Question 74/100
# Q: What type of organization would need large quantities of pure oxygen?
# A: hospitals
# ?: A hospital or a medical facility
# ❌
# ================================================================================
# Question 75/100
# Q: How much Saharan dust falls over the Amazon basin each year?
# A: 27.7 million tons
# ?: The amount of dust transported by wind from the Sahara to the Amazon is about 182 million tons (15%) of dust fall over the Atlantic Ocean, then at 35 degrees west longitude at the eastern coast of South America, 27.7 million tons of dust are windblown and fall on the Caribbean Sea, past 75 degrees west longitude
# ❌
# ================================================================================
# Question 76/100
# Q: How long after a banquet with Tugh Temur did Kusala die?
# A: four days
# ?: Kusala died only four days after a banquet with Tugh Temur
# ❌
# ================================================================================
# Question 77/100
# Q: What type of people were being brought back to the way of truth?
# A: misguided
# ?: The elector answered: "The people who were being brought back were the people who had been brought back by the preaching of Martin Luther. They were the people who had been brought back by the preaching of Martin Luther. They were the people who had been brought back by the preaching of Martin Luther. They were the people who had been brought back by the preaching of Martin Luther. They were the people who had been brought back by the preaching of Martin Luther. They were the people who had been brought back by the preaching of Martin Luther. They were the people who had been brought back by the preaching of Martin Luther. They were the people
# ❌
# ================================================================================
# Question 78/100
# Q: What did the Greek root pharmakos imply?
# A: sorcery or even poison
# ?: The Greek root pharmakos implied that the pharma was a drug seller
# ❌
# ================================================================================
# Question 79/100
# Q: What was Fort Caroline renamed to after the Spanish attack?
# A: San Mateo
# ?: The Spanish renamed the fort San Mateo, and following the ejection of the French, St. Augustine's position as the most important settlement in Florida was solidified. The location of Fort Caroline is subject to debate but a reconstruction of the fort was established on the St. Johns River in 1964
# ❌
# ================================================================================
# Question 80/100
# Q: Which territory did Jochi try to protect that may have led to a dispute with his brothers?
# A: Urgench
# ?: Jochi tried to protect the territory of Khorasan, which was under the control of the Khwarezmian Empire
# ❌
# ================================================================================
# Writing evalMamba790M.json
# Question 81/100
# Q: What ranking does the Super Bowl 50 halftime show have on the list of most watched TV broadcasts?
# A: third
# ?: The Super Bowl 50 halftime show was the third-most watched U.S. broadcast ever
# ❌
# ================================================================================
# Question 82/100
# Q: What music did the fourth soundtrack feature?
# A: music from the 2008–2010 specials
# ?: The fourth soundtrack featured music from the fourth series, the first two series and the specials
# ❌
# ================================================================================
# Question 83/100
# Q: What administration did Ludwig Mies van der Rohe designa buiding?
# A: School of Social Service Administration
# ?: Ludwig Mies van der Rohe designed the Midway, a building that was the first of the university's modern buildings. The Midway was designed to be a building that would be used by the university's students, faculty, and staff. The Midway was designed to be a building that would be used by the university's students, faculty, and staff. The Midway was designed to be a building that would be used by the university's students, faculty, and staff. The Midway was designed to be a building that would be used by the university's students, faculty, and staff. The Midway was designed to be
# ❌
# ================================================================================
# Question 84/100
# Q: What was Manning's passer rating for the 2015 season?
# A: 67.9
# ?:
# ❌
# ================================================================================
# Question 85/100
# Q: Issues dealt with at Westminster are not ones who is able to deal with?
# A: Scottish Parliament
# ?: Yes, they are
# ❌
# ================================================================================
# Question 86/100
# Q: What was the wedding date?
# A: 12 May 1191
# ?: May 12, 1191
# ❌
# ================================================================================
# Question 87/100
# Q: What did the development of this fertile soil provide in hostile environment?
# A: agriculture and silviculture
# ?: The development of this fertile soil allowed agriculture and silviculture in the previously hostile environment; meaning that large portions of the Amazon rainforest are probably the result of centuries of human management, rather than naturally occurring as has previously been supposed. In the region of the Xingu tribe, remains of some of these large settlements in the middle of the Amazon forest were found in 2003 by Michael Heckenberger and colleagues of the University of Florida. Among those were evidence of roads, bridges and large plazas
# ❌
# ================================================================================
# Question 88/100
# Q: Who did the North declare for during the English civil war?
# A: the King
# ?: The North declared for the King
# ❌
# ================================================================================
# Question 89/100
# Q: Which country does the Rhine encounter it's main tributaries?
# A: Germany
# ?: The Rhine meets the Netherlands at the town of Maastricht
# ❌
# ================================================================================
# Question 90/100
# Q: What French animation studio did ABC purchase in 1993?
# A: DIC Entertainment
# ?: DIC Entertainment
# ✅
# ================================================================================
# Question 91/100
# Q: What rive joins the Rhine in Duisburg?
# A: Ruhr
# ?: The Rhine flows into the Rhine-Main-Danube Canal, which is the largest canal in Europe. The canal is a major source of drinking water for the Rhine region
# ❌
# ================================================================================
# Question 92/100
# Q: Which animal's venom did Pierre-Louis Moreau de Maupertuis work with?
# A: scorpion
# ?:
# ❌
# ================================================================================
# Question 93/100
# Q: In the capabilities approach, grow and income are considered a means to an end rather than what?
# A: the end itself
# ?: In the capabilities approach, grow and income are considered a means to an end rather than what?
# ❌
# ================================================================================
# Question 94/100
# Q: Where are Jersey and Guernsey
# A: Channel Islands
# ?: Jersey is a small island in the Channel Islands, and Guernsey is a small island in the Channel Islands
# ❌
# ================================================================================
# Question 95/100
# Q: What was the boat called?
# A: teleautomaton
# ?: The "Teleautomat."
# ❌
# ================================================================================
# Question 96/100
# Q: What did the SNP publicly opine about the oil revenues?
# A: not benefitting Scotland as much as they should
# ?: The SNP argued that the revenues from the oil were not benefitting Scotland as much as they should. The combined effect of these events led to Prime Minister Wilson committing his government to some form of devolved legislature in 1974. However, it was not until 1978 that final legislative proposals for a Scottish Assembly were passed by the United Kingdom Parliament
# ❌
# ================================================================================
# Question 97/100
# Q: How many days after Gagarin's flight did the US House Committee on Science and Astronautics meet?
# A: one day
# ?: The meeting was held on April 12, 1961
# ❌
# ================================================================================
# Question 98/100
# Q: How can function problems typically be restated?
# A: decision problems
# ?: The most common way to restate a function problem is to replace the function with a predicate. For example, the function problem of multiplying two integers can be restated as the predicate
# ❌
# ================================================================================
# Question 99/100
# Q: What does Fortiter Defendit Triumphans mean?
# A: Triumphing by a brave defence
# ?: Fortiter Defendit Triumphans means "Fortiter Defendit Triumphans" in Latin
# ❌
# ================================================================================
# Question 100/100
# Q: Recent studies believe  that ctenophores are the sister lineage to what?
# A: all other animals
# ?: Ctenophores are the sister lineage to all other animal phyla
# ❌
# ================================================================================
# Writing evalMamba790M.json
# Accuracy: 9.0% -- 9 correct and 91 incorrect
# Number of tokens generated: 51052 -- Time: 49.89531755447388 -- Tokens-Per-Sec: 1023.1821842653532

# %%
eval(data[:100], model790m, tokenizer790m, "evalMamba790m_Few_shot.json", few_shot=True, batch_size=32)
# Out:
# Question 1/100
# Q: How many yards did the Panthers get for the division championshipt game?
# A: 487
# ?: 31
# ❌
# ================================================================================
# Question 2/100
# Q: What caused Jacksonville's tourism to become less desirable at the latter half of the 19th century?
# A: yellow fever outbreaks
# ?: Yellow fever
# ❌
# ================================================================================
# Question 3/100
# Q: What are pharmacists in the United Kingdom being increasingly paid for?
# A: medicine use reviews
# ?: Pharmaceutical care
# ❌
# ================================================================================
# Question 4/100
# Q: Geoglyphs dating to what period were found in deforested land along the Amazon River?
# A: AD 0–1250
# ?: Amazon rainforest
# ❌
# ================================================================================
# Question 5/100
# Q: Who does a gender pay gap tend to favor?
# A: males in the labor market
# ?: men
# ❌
# ================================================================================
# Question 6/100
# Q: What is the annual construction industry revenue in 2014?
# A: $960 billion
# ?: $9.1 trillion
# ❌
# ================================================================================
# Question 7/100
# Q: Which sculpture by Michelangelo has a full-size replica in the Cast Courts?
# A: David
# ?: David
# ✅
# ================================================================================
# Question 8/100
# Q: Richard Allen and Absalom Jones were licensed by St. George's Church in what year?
# A: 1784
# ?: 1784
# ✅
# ================================================================================
# Question 9/100
# Q: Where does the Rhine end?
# A: Hoek van Holland
# ?: at the border with Germany
# ❌
# ================================================================================
# Question 10/100
# Q: The V&A has the world's most comprehensive collection of sculptures from which period?
# A: post-classical European
# ?: The V&A has the world's most comprehensive collection of sculptures from which period?
# ❌
# ================================================================================
# Question 11/100
# Q: Which country rationed gasoline and heating gas?
# A: Sweden
# ?: Germany
# ❌
# ================================================================================
# Question 12/100
# Q: The United States is divided into how many jurisdictions?
# A: five
# ?: five
# ✅
# ================================================================================
# Question 13/100
# Q: What is an example of a machine model that deviates from a generally accepted multi-tape Turing machine?
# A: random access machines
# ?: Random access machine
# ❌
# ================================================================================
# Question 14/100
# Q: What company developed the most successful steam engine indicator?
# A: Charles Porter
# ?: Porter
# ❌
# ================================================================================
# Question 15/100
# Q: Who dates rocks, precisely, within the stratigraphic section?
# A: Geochronologists
# ?: geochronologists
# ✅
# ================================================================================
# Question 16/100
# Q: Who formulated the idea of clonal selection theory of immunity?
# A: Frank Burnet
# ?: Frank Burnet
# ✅
# ================================================================================
# Question 17/100
# Q: What is the second most abundant element?
# A: helium
# ?: oxygen
# ❌
# ================================================================================
# Question 18/100
# Q: what was invented in 1880 that revolutionized warfare?
# A: the machine gun
# ?: machine gun
# ❌
# ================================================================================
# Question 19/100
# Q: When did Watt finish the development of his improvements to Newcomen's engine?
# A: 1775
# ?: 1777
# ❌
# ================================================================================
# Question 20/100
# Q: What is the largest item from Italy that is part of the sculpture collection?
# A: Chancel Chapel
# ?: The Chancel Chapel from Santa Chiara Florence dated c. 1564 with plaster
# ❌
# ================================================================================
# Writing evalMamba790m_Few_shot.json
# Question 21/100
# Q: Antibodies are transferred to the gut of the infant through what means?
# A: Breast milk or colostrum
# ?: passive immunity
# ❌
# ================================================================================
# Question 22/100
# Q: Which century was there a program to straighten the Rhine?
# A: 19th Century
# ?: Rhine straightening program
# ❌
# ================================================================================
# Question 23/100
# Q: Where was the first horse racetrack located?
# A: Pole Mokotowskie
# ?: Praga
# ❌
# ================================================================================
# Question 24/100
# Q: What did the Islamic State proclaim itself in 2014?
# A: a caliphate
# ?: Caliphate
# ❌
# ================================================================================
# Question 25/100
# Q: What plants don't need light to make chloroplasts?
# A: Gymnosperms
# ?: Gymnosperms
# ✅
# ================================================================================
# Question 26/100
# Q: Where was Dyrrachium located?
# A: the Adriatic
# ?: in the Adriatic Sea
# ❌
# ================================================================================
# Question 27/100
# Q: What is the expression used to denote a worst case complexity as expressed by time taken?
# A: O(n2)
# ?: O(n log n)
# ❌
# ================================================================================
# Question 28/100
# Q: How would the capabilities approach achieve it's goal?
# A: through increasing functionings
# ?: It would increase the number of people who are able to pursue their valued goals
# ❌
# ================================================================================
# Question 29/100
# Q: Within what variable is L constrained according to the space hierarchy theorem?
# A: PSPACE
# ?: L is constrained according to the space hierarchy theorem
# ❌
# ================================================================================
# Question 30/100
# Q: What are the "Big Five" animals in Kenya?
# A: lion, leopard, buffalo, rhinoceros, and elephant
# ?: lion, leopard, buffalo, rhinoceros, elephant
# ❌
# ================================================================================
# Question 31/100
# Q: What is another way of referring to stators?
# A: static discs
# ?: stators
# ❌
# ================================================================================
# Question 32/100
# Q: When was the new two-year affiliate agreement approved?
# A: 2002
# ?: 2002
# ✅
# ================================================================================
# Question 33/100
# Q: What type of materials inside the cabin were removed to help prevent more fire hazards in the future?
# A: flammable cabin and space suit materials
# ?: Block II
# ❌
# ================================================================================
# Question 34/100
# Q: How many nations contain "Amazonas" in their names?
# A: States or departments in four nations contain "Amazonas" in their names.
# ?: Amazonas
# ❌
# ================================================================================
# Question 35/100
# Q: What was Tesla's position with Westinghouse?
# A: consultant
# ?: Consultant
# ✅
# ================================================================================
# Question 36/100
# Q: What year were the first Doctor Who stories available on CD?
# A: 1999
# ?: 1963
# ❌
# ================================================================================
# Question 37/100
# Q: What is the term for a task that generally lends itself to being solved by a computer?
# A: computational problems
# ?: computational problem
# ❌
# ================================================================================
# Question 38/100
# Q: What was happening to subscriber numbers in other areas of europe?
# A: flattened
# ?: Germany
# ❌
# ================================================================================
# Question 39/100
# Q: Dutch architect Janjaap Ruijssenaars's performative architecture 3D-printed building is scheduled to be built when?
# A: Working versions of 3D-printing building technology are already printing
# ?: 2024
# ❌
# ================================================================================
# Question 40/100
# Q: When was the most recent Super Bowl hosted in the South Florida/Miami area?
# A: 2010
# ?: Super Bowl XLIV
# ❌
# ================================================================================
# Writing evalMamba790m_Few_shot.json
# Question 41/100
# Q: The atomic number of the periodic table for oxygen?
# A: 8
# ?: 8
# ✅
# ================================================================================
# Question 42/100
# Q: How were enemy prisoners used tactically by Mongol armies?
# A: driving them in front of the army
# ?: to lure enemy groups away from the larger group and defend position for ambush, counterattack, and siege
# ❌
# ================================================================================
# Question 43/100
# Q: What is the CJEU's duty?
# A: ensure that in the interpretation and application of the Treaties the law is observed
# ?: to interpret the treaties
# ❌
# ================================================================================
# Question 44/100
# Q: Who was an important figure in the twentieth-century Islamic revival in India?
# A: Sayyid Abul Ala Maududi
# ?: Sayyid Abul Ala Maududi
# ✅
# ================================================================================
# Question 45/100
# Q: When did the ban on cigarette advertising take effect for television networks?
# A: January 2, 1971
# ?: 1971
# ❌
# ================================================================================
# Question 46/100
# Q: In what form is oxygen transported in smaller containers?
# A: compressed gas
# ?: in liquid form
# ❌
# ================================================================================
# Question 47/100
# Q: When rich countries trade with poor countries, whose wages increase?
# A: workers in the poor countries
# ?: rich countries
# ❌
# ================================================================================
# Question 48/100
# Q: Who led the Science and Environmental Policy Project?
# A: Fred Singer
# ?: Fred Singer
# ✅
# ================================================================================
# Question 49/100
# Q: In what year did the NFL switch to a 16-game regular season?
# A: 1978
# ?: 2016
# ❌
# ================================================================================
# Question 50/100
# Q: What does computational complexity theory most specifically seek to answer?
# A: computational problems
# ?: Computational complexity
# ❌
# ================================================================================
# Question 51/100
# Q: What was the final score of Super Bowl 50?
# A: 24–10
# ?: 24–10
# ✅
# ================================================================================
# Question 52/100
# Q: What did Luther call the mass instead of sacrifice?
# A: a gift
# ?: The Mass
# ❌
# ================================================================================
# Question 53/100
# Q: What did Queen Elizabeth II open in Newcastle in 1981?
# A: A bridge
# ?: Metro
# ❌
# ================================================================================
# Question 54/100
# Q: What kind of disorders are the result of an overactive immune response?
# A: autoimmune disorders
# ?: Autoimmune disorders
# ✅
# ================================================================================
# Question 55/100
# Q: Where hotel did the Panthers stay at?
# A: San Jose Marriott.
# ?: Stanford University
# ❌
# ================================================================================
# Question 56/100
# Q: Why did Westinghouse not secure a patent for a similar motor?
# A: decided Tesla's patent would probably control the market
# ?: Westinghouse Electric & Manufacturing Company
# ❌
# ================================================================================
# Question 57/100
# Q: What words to they think are linked to the work Kenya?
# A: Kirinyaga, Kirenyaa and Kiinyaa
# ?: Kenya
# ❌
# ================================================================================
# Question 58/100
# Q: When was the first known historical reference to immunity?
# A: Athens in 430 BC
# ?: The First Crusade
# ❌
# ================================================================================
# Question 59/100
# Q: What was the name of the Mongol Empire's legal code?
# A: Yassa
# ?: Yassa
# ✅
# ================================================================================
# Question 60/100
# Q: When had the Six Ministries existed?
# A: since the Sui and Tang dynasties
# ?: Before Yuan
# ❌
# ================================================================================
# Writing evalMamba790m_Few_shot.json
# Question 61/100
# Q: How to Baptized Members become Professing Members?
# A: confirmation and sometimes the profession of faith
# ?: Confirmation
# ❌
# ================================================================================
# Question 62/100
# Q: After asking if the books were his, what else did Eck ask Luther?
# A: stood by their contents
# ?: Luther answered that he was the author of the books, but that he did not stand by their contents
# ❌
# ================================================================================
# Question 63/100
# Q: When did the Pope warned Luther of excommunication?
# A: 15 June 1520
# ?: 1520
# ❌
# ================================================================================
# Question 64/100
# Q: When large groups of people all boycott a system or don't pay taxes it can be considered?
# A: coercive
# ?: Coercive
# ✅
# ================================================================================
# Question 65/100
# Q: What ABC action series went up against NBC's variety shows in Fall 1957?
# A: Zorro
# ?: The Adventures of Superman
# ❌
# ================================================================================
# Question 66/100
# Q: What was the significance of victory at Forth Niagara for British?
# A: cut off the French frontier forts further to the west and south
# ?: victory at Forth Niagara for British
# ❌
# ================================================================================
# Question 67/100
# Q: What is the Latin name for Black Death?
# A: atra mors
# ?: atra mors
# ✅
# ================================================================================
# Question 68/100
# Q: What are the phagocytes that are located in tissues in contact with the external environment called?
# A: Dendritic cells
# ?: dendritic cells
# ✅
# ================================================================================
# Question 69/100
# Q: What profession was Nathan Alterman?
# A: poet
# ?: lawyer
# ❌
# ================================================================================
# Question 70/100
# Q: What type of vote must the Parliament have to either block or suggest changes to the Commission's proposals?
# A: a majority
# ?: absolute majority
# ❌
# ================================================================================
# Question 71/100
# Q: What percentage of money raised was earmarked for causes in the San Francisco area?
# A: 25 percent
# ?: 25 percent
# ✅
# ================================================================================
# Question 72/100
# Q: In which year was the Musical Instruments gallery closed?
# A: 2010
# ?: 25 February 2010
# ❌
# ================================================================================
# Question 73/100
# Q: What scientific field's theory has received contributions from the steam engine?
# A: thermodynamic
# ?: Steam engine
# ❌
# ================================================================================
# Question 74/100
# Q: What type of organization would need large quantities of pure oxygen?
# A: hospitals
# ?: oxygen storage tanks
# ❌
# ================================================================================
# Question 75/100
# Q: How much Saharan dust falls over the Amazon basin each year?
# A: 27.7 million tons
# ?: 1.5 million tons
# ❌
# ================================================================================
# Question 76/100
# Q: How long after a banquet with Tugh Temur did Kusala die?
# A: four days
# ?: one day
# ❌
# ================================================================================
# Question 77/100
# Q: What type of people were being brought back to the way of truth?
# A: misguided
# ?: Lutherans
# ❌
# ================================================================================
# Question 78/100
# Q: What did the Greek root pharmakos imply?
# A: sorcery or even poison
# ?: drug
# ❌
# ================================================================================
# Question 79/100
# Q: What was Fort Caroline renamed to after the Spanish attack?
# A: San Mateo
# ?: Fort Caroline
# ❌
# ================================================================================
# Question 80/100
# Q: Which territory did Jochi try to protect that may have led to a dispute with his brothers?
# A: Urgench
# ?: Urgench
# ✅
# ================================================================================
# Writing evalMamba790m_Few_shot.json
# Question 81/100
# Q: What ranking does the Super Bowl 50 halftime show have on the list of most watched TV broadcasts?
# A: third
# ?: #1
# ❌
# ================================================================================
# Question 82/100
# Q: What music did the fourth soundtrack feature?
# A: music from the 2008–2010 specials
# ?: Christmas Carol
# ❌
# ================================================================================
# Question 83/100
# Q: What administration did Ludwig Mies van der Rohe designa buiding?
# A: School of Social Service Administration
# ?: Ludwig Mies van der Rohe
# ❌
# ================================================================================
# Question 84/100
# Q: What was Manning's passer rating for the 2015 season?
# A: 67.9
# ?: 86.4
# ❌
# ================================================================================
# Question 85/100
# Q: Issues dealt with at Westminster are not ones who is able to deal with?
# A: Scottish Parliament
# ?: No
# ❌
# ================================================================================
# Question 86/100
# Q: What was the wedding date?
# A: 12 May 1191
# ?: 12 May 1191
# ✅
# ================================================================================
# Question 87/100
# Q: What did the development of this fertile soil provide in hostile environment?
# A: agriculture and silviculture
# ?: Amazon forest
# ❌
# ================================================================================
# Question 88/100
# Q: Who did the North declare for during the English civil war?
# A: the King
# ?: Charles I
# ❌
# ================================================================================
# Question 89/100
# Q: Which country does the Rhine encounter it's main tributaries?
# A: Germany
# ?: Germany
# ✅
# ================================================================================
# Question 90/100
# Q: What French animation studio did ABC purchase in 1993?
# A: DIC Entertainment
# ?: Capital Cities/ABC
# ❌
# ================================================================================
# Question 91/100
# Q: What rive joins the Rhine in Duisburg?
# A: Ruhr
# ?: Rhine
# ❌
# ================================================================================
# Question 92/100
# Q: Which animal's venom did Pierre-Louis Moreau de Maupertuis work with?
# A: scorpion
# ?: scorpion venom
# ❌
# ================================================================================
# Question 93/100
# Q: In the capabilities approach, grow and income are considered a means to an end rather than what?
# A: the end itself
# ?: the end itself
# ✅
# ================================================================================
# Question 94/100
# Q: Where are Jersey and Guernsey
# A: Channel Islands
# ?: Channel Islands
# ✅
# ================================================================================
# Question 95/100
# Q: What was the boat called?
# A: teleautomaton
# ?: Tesla's Teleautomaton
# ❌
# ================================================================================
# Question 96/100
# Q: What did the SNP publicly opine about the oil revenues?
# A: not benefitting Scotland as much as they should
# ?: They opined that the oil revenues should be used to fund a Scottish Assembly
# ❌
# ================================================================================
# Question 97/100
# Q: How many days after Gagarin's flight did the US House Committee on Science and Astronautics meet?
# A: one day
# ?: one day
# ✅
# ================================================================================
# Question 98/100
# Q: How can function problems typically be restated?
# A: decision problems
# ?: by using the same variables
# ❌
# ================================================================================
# Question 99/100
# Q: What does Fortiter Defendit Triumphans mean?
# A: Triumphing by a brave defence
# ?: Fortiter Defendit Triumphans
# ❌
# ================================================================================
# Question 100/100
# Q: Recent studies believe  that ctenophores are the sister lineage to what?
# A: all other animals
# ?: Porifera
# ❌
# ================================================================================
# Writing evalMamba790m_Few_shot.json
# Accuracy: 24.0% -- 24 correct and 76 incorrect
# Number of tokens generated: 55527 -- Time: 72.89155960083008 -- Tokens-Per-Sec: 761.7754415473869

# %%
tokenizer790m = None
model790m = None

gc.collect()
# Out:
# 0

# %% [markdown]
# ## 2.8B model

# %%
tokenizer2_8b = AutoTokenizer.from_pretrained("state-spaces/mamba-2.8b-hf", padding_side='left')
model2_8b = MambaForCausalLM.from_pretrained("state-spaces/mamba-2.8b-hf")
tokenizer2_8b.eos_token = "<|endoftext|>"
tokenizer2_8b.pad_token = tokenizer2_8b.eos_token
# Out:
# tokenizer_config.json:   0%|          | 0.00/4.79k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# config.json:   0%|          | 0.00/843 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/50.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/1.15G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/137 [00:00<?, ?B/s]

# %%
eval(data[:100], model2_8b, tokenizer2_8b, "evalMamba2_8b.json", few_shot=False, batch_size=8)
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Question 1/100
# Q: How many yards did the Panthers get for the division championshipt game?
# A: 487
# ?: They got 603 yards
# ❌
# ================================================================================
# Question 2/100
# Q: What caused Jacksonville's tourism to become less desirable at the latter half of the 19th century?
# A: yellow fever outbreaks
# ?: The yellow fever outbreaks in the late 19th century
# ❌
# ================================================================================
# Question 3/100
# Q: What are pharmacists in the United Kingdom being increasingly paid for?
# A: medicine use reviews
# ?: In the United Kingdom, pharmacists who undertake additional training are obtaining prescribing rights and this is because of pharmacy education. They are also being paid for consultant pharmacists, who traditionally operated primarily in nursing homes are now expanding into direct consultation with patients, under the banner of "senior care pharmacy."
# ❌
# ================================================================================
# Question 4/100
# Q: Geoglyphs dating to what period were found in deforested land along the Amazon River?
# A: AD 0–1250
# ?: The geoglyphs were discovered in 1977 by Ondemar Dias and Alceu Ranzi
# ❌
# ================================================================================
# Question 5/100
# Q: Who does a gender pay gap tend to favor?
# A: males in the labor market
# ?: Women
# ❌
# ================================================================================
# Question 6/100
# Q: What is the annual construction industry revenue in 2014?
# A: $960 billion
# ?: $960 billion
# ✅
# ================================================================================
# Question 7/100
# Q: Which sculpture by Michelangelo has a full-size replica in the Cast Courts?
# A: David
# ?: The David
# ❌
# ================================================================================
# Question 8/100
# Q: Richard Allen and Absalom Jones were licensed by St. George's Church in what year?
# A: 1784
# ?: 1784
# ✅
# ================================================================================
# Question 9/100
# Q: Where does the Rhine end?
# A: Hoek van Holland
# ?: At the Rhine-Meuse-Scheldt delta, where the river flows into the North Sea
# ❌
# ================================================================================
# Question 10/100
# Q: The V&A has the world's most comprehensive collection of sculptures from which period?
# A: post-classical European
# ?: The V&A has the world's most comprehensive collection of sculptures from the Roman period
# ❌
# ================================================================================
# Question 11/100
# Q: Which country rationed gasoline and heating gas?
# A: Sweden
# ?: Sweden
# ✅
# ================================================================================
# Question 12/100
# Q: The United States is divided into how many jurisdictions?
# A: five
# ?: There are five jurisdictions: Northeastern, Southeastern, North Central, South Central and Western
# ❌
# ================================================================================
# Question 13/100
# Q: What is an example of a machine model that deviates from a generally accepted multi-tape Turing machine?
# A: random access machines
# ?: The model of a random access machine (RAM) is a deterministic machine model that differs from the standard multi-tape Turing machine in that it can access the contents of any cell in the tape at any time
# ❌
# ================================================================================
# Question 14/100
# Q: What company developed the most successful steam engine indicator?
# A: Charles Porter
# ?: The company that developed the most successful steam engine indicator was Charles Porter
# ❌
# ================================================================================
# Question 15/100
# Q: Who dates rocks, precisely, within the stratigraphic section?
# A: Geochronologists
# ?: The geochronologist
# ❌
# ================================================================================
# Question 16/100
# Q: Who formulated the idea of clonal selection theory of immunity?
# A: Frank Burnet
# ?: Frank Burnet, a British immunologist, proposed the clonal selection theory of immunity in the mid-1950s
# ❌
# ================================================================================
# Question 17/100
# Q: What is the second most abundant element?
# A: helium
# ?: Oxygen
# ❌
# ================================================================================
# Question 18/100
# Q: what was invented in 1880 that revolutionized warfare?
# A: the machine gun
# ?: the machine gun
# ✅
# ================================================================================
# Question 19/100
# Q: When did Watt finish the development of his improvements to Newcomen's engine?
# A: 1775
# ?: In 1763, Watt patented his first engine, which was a direct descendant of Newcomen's engine
# ❌
# ================================================================================
# Question 20/100
# Q: What is the largest item from Italy that is part of the sculpture collection?
# A: Chancel Chapel
# ?: The Chancel Chapel from Santa Chiara Florence dated 1493–1500, designed by Giuliano da Sangallo it is 11.1 metres in height by 5.4 metres square, it includes a grand sculpted tabernacle by Antonio Rossellino and coloured terracotta decoration
# ❌
# ================================================================================
# Writing evalMamba2_8b.json
# Question 21/100
# Q: Antibodies are transferred to the gut of the infant through what means?
# A: Breast milk or colostrum
# ?: The mother’s milk contains antibodies that are transferred to the infant through breast milk or colostrum
# ❌
# ================================================================================
# Question 22/100
# Q: Which century was there a program to straighten the Rhine?
# A: 19th Century
# ?: The 19th Century
# ❌
# ================================================================================
# Question 23/100
# Q: Where was the first horse racetrack located?
# A: Pole Mokotowskie
# ?: In Praga. The first horse racetrack was established in Praga in 1865–1871 and designed by Jan Dobrowolski. In 1927 a bear run, still open today, was established on the park grounds, and in 1952 a race track was established on the park grounds
# ❌
# ================================================================================
# Question 24/100
# Q: What did the Islamic State proclaim itself in 2014?
# A: a caliphate
# ?: The Islamic State is a caliphate
# ❌
# ================================================================================
# Question 25/100
# Q: What plants don't need light to make chloroplasts?
# A: Gymnosperms
# ?: Gymnosperms
# ✅
# ================================================================================
# Question 26/100
# Q: Where was Dyrrachium located?
# A: the Adriatic
# ?: Dyrrachium was located on the coast of the Adriatic Sea, in the region of modern-day Albania
# ❌
# ================================================================================
# Question 27/100
# Q: What is the expression used to denote a worst case complexity as expressed by time taken?
# A: O(n2)
# ?: O(n2)
# ✅
# ================================================================================
# Question 28/100
# Q: How would the capabilities approach achieve it's goal?
# A: through increasing functionings
# ?: The capabilities approach would achieve it's goal by increasing the functionings and capabilities of people
# ❌
# ================================================================================
# Question 29/100
# Q: Within what variable is L constrained according to the space hierarchy theorem?
# A: PSPACE
# ?: L is constrained within the space hierarchy theorem
# ❌
# ================================================================================
# Question 30/100
# Q: What are the "Big Five" animals in Kenya?
# A: lion, leopard, buffalo, rhinoceros, and elephant
# ?: The "Big Five" are the lion, leopard, buffalo, rhinoceros, and elephant
# ❌
# ================================================================================
# Question 31/100
# Q: What is another way of referring to stators?
# A: static discs
# ?: The stator is the stationary part of a generator. It is the part that is not rotating. The rotor is the part that is rotating
# ❌
# ================================================================================
# Question 32/100
# Q: When was the new two-year affiliate agreement approved?
# A: 2002
# ?: The agreement was approved in September 2002
# ❌
# ================================================================================
# Question 33/100
# Q: What type of materials inside the cabin were removed to help prevent more fire hazards in the future?
# A: flammable cabin and space suit materials
# ?: The cabin was redesigned to be more fire resistant. The cabin was made of a fire-resistant material called Kevlar, which is a synthetic fiber that is used in bulletproof vests. The cabin was also redesigned to have a more streamlined shape, which helped to reduce the amount of heat that was generated during the launch
# ❌
# ================================================================================
# Question 34/100
# Q: How many nations contain "Amazonas" in their names?
# A: States or departments in four nations contain "Amazonas" in their names.
# ?:
# ❌
# ================================================================================
# Question 35/100
# Q: What was Tesla's position with Westinghouse?
# A: consultant
# ?: Tesla was hired as a consultant to Westinghouse
# ❌
# ================================================================================
# Question 36/100
# Q: What year were the first Doctor Who stories available on CD?
# A: 1999
# ?: The first Doctor Who story available on CD was The Daleks' Master Plan, released in 1999
# ❌
# ================================================================================
# Question 37/100
# Q: What is the term for a task that generally lends itself to being solved by a computer?
# A: computational problems
# ?: Computational problem
# ❌
# ================================================================================
# Question 38/100
# Q: What was happening to subscriber numbers in other areas of europe?
# A: flattened
# ?: The growth in the UK was driven by the introduction of the digital terrestrial television service in 2006. This was followed by the launch of the Sky+ HD service in 2010
# ❌
# ================================================================================
# Question 39/100
# Q: Dutch architect Janjaap Ruijssenaars's performative architecture 3D-printed building is scheduled to be built when?
# A: Working versions of 3D-printing building technology are already printing
# ?: 2014
# ❌
# ================================================================================
# Question 40/100
# Q: When was the most recent Super Bowl hosted in the South Florida/Miami area?
# A: 2010
# ?: Super Bowl XIX was held at Sun Life Stadium in Miami Gardens, Florida, on January 27, 1985
# ❌
# ================================================================================
# Writing evalMamba2_8b.json
# Question 41/100
# Q: The atomic number of the periodic table for oxygen?
# A: 8
# ?: 8
# ✅
# ================================================================================
# Question 42/100
# Q: How were enemy prisoners used tactically by Mongol armies?
# A: driving them in front of the army
# ?: The Mongols used prisoners to great effect. They were used as scouts, spies, and as human shields. They were also used as a means of intimidation
# ❌
# ================================================================================
# Question 43/100
# Q: What is the CJEU's duty?
# A: ensure that in the interpretation and application of the Treaties the law is observed
# ?: The CJEU's duty is to "ensure that in the interpretation and application of the Treaties the law is observed", although realistically it has the ability to expand and develop the law according to the principles it deems to be appropriate
# ❌
# ================================================================================
# Question 44/100
# Q: Who was an important figure in the twentieth-century Islamic revival in India?
# A: Sayyid Abul Ala Maududi
# ?: Sayyid Abul Ala Maududi
# ✅
# ================================================================================
# Question 45/100
# Q: When did the ban on cigarette advertising take effect for television networks?
# A: January 2, 1971
# ?: The ban on cigarette advertising took effect on January 2, 1971, for all television networks, including ABC Great States, the Central West division of ABC Theatres, was sold to Henry Plitt in 1974. On January 17, 1972, Elton Rule was named President and Chief Operating Officer of ABC a few months after Goldenson reduced his role in the company after suffering a heart attack
# ❌
# ================================================================================
# Question 46/100
# Q: In what form is oxygen transported in smaller containers?
# A: compressed gas
# ?: Liquid oxygen is transported in specially insulated tankers, since one liter of liquefied oxygen is equivalent to 840 liters of gaseous oxygen at atmospheric pressure and 20 °C (68 °F)
# ❌
# ================================================================================
# Question 47/100
# Q: When rich countries trade with poor countries, whose wages increase?
# A: workers in the poor countries
# ?: The wages of low-skilled workers in the rich countries may see increased competition from low-skilled workers in the poor countries
# ❌
# ================================================================================
# Question 48/100
# Q: Who led the Science and Environmental Policy Project?
# A: Fred Singer
# ?: Fred Singer
# ✅
# ================================================================================
# Question 49/100
# Q: In what year did the NFL switch to a 16-game regular season?
# A: 1978
# ?: The NFL switched to a 16-game regular season in 1978
# ❌
# ================================================================================
# Question 50/100
# Q: What does computational complexity theory most specifically seek to answer?
# A: computational problems
# ?: The question of whether a problem is solvable in polynomial time
# ❌
# ================================================================================
# Question 51/100
# Q: What was the final score of Super Bowl 50?
# A: 24–10
# ?: Denver Broncos 24, Carolina Panthers 10
# ❌
# ================================================================================
# Question 52/100
# Q: What did Luther call the mass instead of sacrifice?
# A: a gift
# ?: The mass was a gift, not a sacrifice
# ❌
# ================================================================================
# Question 53/100
# Q: What did Queen Elizabeth II open in Newcastle in 1981?
# A: A bridge
# ?: The Tyne and Wear Metro
# ❌
# ================================================================================
# Question 54/100
# Q: What kind of disorders are the result of an overactive immune response?
# A: autoimmune disorders
# ?: Autoimmune disorders are the result of an overactive immune response. Autoimmune disorders are characterized by the immune system attacking the body's own tissues. Autoimmune disorders are classified into two groups:
# ❌
# ================================================================================
# Question 55/100
# Q: Where hotel did the Panthers stay at?
# A: San Jose Marriott.
# ?: The San Jose Marriott.
# ❌
# ================================================================================
# Question 56/100
# Q: Why did Westinghouse not secure a patent for a similar motor?
# A: decided Tesla's patent would probably control the market
# ?: Because he was a good friend of Tesla and wanted to help him
# ❌
# ================================================================================
# Question 57/100
# Q: What words to they think are linked to the work Kenya?
# A: Kirinyaga, Kirenyaa and Kiinyaa
# ?: KENYA, KENYATTA, KENYATTA, KENYATTA, KENYATTA, KENYATTA, KENYATTA, KENYATTA, KENYATTA, KENYATTA, KENYATTA, KENYATTA, KENYATTA, KENYATTA, KENYATTA, KENYATTA, KENYATTA, KENYATTA, KENYATTA, KENYATTA, KENYATTA, KENYAT
# ❌
# ================================================================================
# Question 58/100
# Q: When was the first known historical reference to immunity?
# A: Athens in 430 BC
# ?: The first known reference to immunity was during the plague of Athens in 430 BC. Thucydides noted that people who had recovered from a previous bout of the disease could nurse the sick without contracting the illness a second time. In the 18th century, Pierre-Louis Moreau de Maupertuis made experiments with scorpion venom and observed that certain dogs and mice were immune to this venom. This and other observations of acquired immunity were later exploited by Louis Pasteur in his development of vaccination and his proposed germ theory of disease. Pasteur's theory was in direct opposition to contemporary theories of disease, such as the mi
# ❌
# ================================================================================
# Question 59/100
# Q: What was the name of the Mongol Empire's legal code?
# A: Yassa
# ?: Yassa
# ✅
# ================================================================================
# Question 60/100
# Q: When had the Six Ministries existed?
# A: since the Sui and Tang dynasties
# ?: The Six Ministries were established in the Yuan dynasty
# ❌
# ================================================================================
# Writing evalMamba2_8b.json
# Question 61/100
# Q: How to Baptized Members become Professing Members?
# A: confirmation and sometimes the profession of faith
# ?: Baptized Members become Professing Members through confirmation and sometimes the profession of faith. Individuals who were not previously baptized are baptized as part of their profession of faith and thus become Professing Members in this manner. Individuals may also become a Professing Member through transfer from another Christian denomination
# ❌
# ================================================================================
# Question 62/100
# Q: After asking if the books were his, what else did Eck ask Luther?
# A: stood by their contents
# ?: He asked Luther if he was willing to recant his views. Luther replied that he was not willing to recant, but that he would gladly accept the right of the Pope to judge him
# ❌
# ================================================================================
# Question 63/100
# Q: When did the Pope warned Luther of excommunication?
# A: 15 June 1520
# ?: On 15 June 1520, the Pope warned Luther with the papal bull (edict) Exsurge Domine that he risked excommunication unless he recanted 41 sentences drawn from his writings, including the 95 Theses, within 60 days
# ❌
# ================================================================================
# Question 64/100
# Q: When large groups of people all boycott a system or don't pay taxes it can be considered?
# A: coercive
# ?: Coercive
# ✅
# ================================================================================
# Question 65/100
# Q: What ABC action series went up against NBC's variety shows in Fall 1957?
# A: Zorro
# ?: The ABC action series that went up against NBC's variety shows in Fall 1957 were:
# ❌
# ================================================================================
# Question 66/100
# Q: What was the significance of victory at Forth Niagara for British?
# A: cut off the French frontier forts further to the west and south
# ?: The British victory at Fort Niagara was a significant victory for the British. It was the first time that the British had been able to successfully defend a fort against a French attack. The British had been able to successfully defend the fort against the French in 1759, but the French had been able to capture the fort in 1760. The British victory at Fort Niagara was also significant because it was the first time that the British had been able to successfully defend a fort against a French attack. The British had been able to successfully defend the fort against the French in 1759, but the French had been able to capture the fort in 17
# ❌
# ================================================================================
# Question 67/100
# Q: What is the Latin name for Black Death?
# A: atra mors
# ?: Atra mors
# ✅
# ================================================================================
# Question 68/100
# Q: What are the phagocytes that are located in tissues in contact with the external environment called?
# A: Dendritic cells
# ?: Dendritic cells
# ✅
# ================================================================================
# Question 69/100
# Q: What profession was Nathan Alterman?
# A: poet
# ?: He was a lawyer
# ❌
# ================================================================================
# Question 70/100
# Q: What type of vote must the Parliament have to either block or suggest changes to the Commission's proposals?
# A: a majority
# ?: The Parliament must vote by a majority of all MEPs (not just those present) to block or suggest changes, and the Council must vote by qualified majority to approve changes, but by unanimity to block Commission amendment. Where the different institutions cannot agree at any stage, a "Conciliation Committee" is convened, representing member states, ministers and the Commission to try and get agreement on a joint text: if this works, it will be sent back to the Parliament and Council to approve by absolute and qualified majority. This means, legislation can be blocked by a majority in Parliament, a minority in the Council, and a majority in the
# ❌
# ================================================================================
# Question 71/100
# Q: What percentage of money raised was earmarked for causes in the San Francisco area?
# A: 25 percent
# ?: The Super Bowl 50 Host Committee has vowed to be "the most giving Super Bowl ever", and will dedicate 25 percent of all money it raises for philanthropic causes in the Bay Area. The committee created the 50 fund as its philanthropic initiative and focuses on providing grants to aid with youth development, community investment and sustainable environments
# ❌
# ================================================================================
# Question 72/100
# Q: In which year was the Musical Instruments gallery closed?
# A: 2010
# ?: 2010
# ✅
# ================================================================================
# Question 73/100
# Q: What scientific field's theory has received contributions from the steam engine?
# A: thermodynamic
# ?: The steam engine contributed much to the development of thermodynamic theory; however, the only applications of scientific theory that influenced the steam engine were the original concepts of harnessing the power of steam and atmospheric pressure and knowledge of properties of heat and steam. The experimental measurements made by Watt on a model steam engine led to the development of the separate condenser. Watt independently discovered latent heat, which was confirmed by the original discoverer Joseph Black, who also advised Watt on experimental procedures. Watt was also aware of the change in the boiling point of water with pressure. Otherwise, the improvements to the engine itself were more mechanical in nature
# ❌
# ================================================================================
# Question 74/100
# Q: What type of organization would need large quantities of pure oxygen?
# A: hospitals
# ?: Hospitals, laboratories, and other medical facilities that require large quantities of oxygen for patients
# ❌
# ================================================================================
# Question 75/100
# Q: How much Saharan dust falls over the Amazon basin each year?
# A: 27.7 million tons
# ?: About 132 million tons
# ❌
# ================================================================================
# Question 76/100
# Q: How long after a banquet with Tugh Temur did Kusala die?
# A: four days
# ?: Kusala died three days after a banquet with Tugh Temür
# ❌
# ================================================================================
# Question 77/100
# Q: What type of people were being brought back to the way of truth?
# A: misguided
# ?: The people who had been misled by the false teachings of the Roman Catholic Church
# ❌
# ================================================================================
# Question 78/100
# Q: What did the Greek root pharmakos imply?
# A: sorcery or even poison
# ?: The word pharmakos implied sorcery or even poison
# ❌
# ================================================================================
# Question 79/100
# Q: What was Fort Caroline renamed to after the Spanish attack?
# A: San Mateo
# ?: San Mateo
# ✅
# ================================================================================
# Question 80/100
# Q: Which territory did Jochi try to protect that may have led to a dispute with his brothers?
# A: Urgench
# ?: Khorasan
# ❌
# ================================================================================
# Writing evalMamba2_8b.json
# Question 81/100
# Q: What ranking does the Super Bowl 50 halftime show have on the list of most watched TV broadcasts?
# A: third
# ?: The Super Bowl 50 halftime show was the most watched U.S. broadcast ever, with an average of 34.5 million viewers. The Super Bowl 50 halftime show was also the most watched U.S. broadcast in the history of the Super Bowl
# ❌
# ================================================================================
# Question 82/100
# Q: What music did the fourth soundtrack feature?
# A: music from the 2008–2010 specials
# ?: The fourth soundtrack featured music from the 2008–2010 specials (The Next Doctor to End of Time Part 2)
# ❌
# ================================================================================
# Question 83/100
# Q: What administration did Ludwig Mies van der Rohe designa buiding?
# A: School of Social Service Administration
# ?: The Midway
# ❌
# ================================================================================
# Question 84/100
# Q: What was Manning's passer rating for the 2015 season?
# A: 67.9
# ?: Manning's passer rating was 86.4, which was the lowest of his career
# ❌
# ================================================================================
# Question 85/100
# Q: Issues dealt with at Westminster are not ones who is able to deal with?
# A: Scottish Parliament
# ?: Yes, these are reserved matters
# ❌
# ================================================================================
# Question 86/100
# Q: What was the wedding date?
# A: 12 May 1191
# ?: 12 May 1191
# ✅
# ================================================================================
# Question 87/100
# Q: What did the development of this fertile soil provide in hostile environment?
# A: agriculture and silviculture
# ?: The fertile soil was created by the use of slash and burn agriculture. The slash and burn agriculture is a method of agriculture where the land is cleared of vegetation and then burned. The slash and burn agriculture is used by many indigenous peoples in the Amazon rainforest. The slash and burn agriculture is used to clear the land for agriculture and to clear the land for hunting. The slash and burn agriculture is also used to clear the land for the construction of roads and bridges
# ❌
# ================================================================================
# Question 88/100
# Q: Who did the North declare for during the English civil war?
# A: the King
# ?: The Scots
# ❌
# ================================================================================
# Question 89/100
# Q: Which country does the Rhine encounter it's main tributaries?
# A: Germany
# ?: Germany
# ✅
# ================================================================================
# Question 90/100
# Q: What French animation studio did ABC purchase in 1993?
# A: DIC Entertainment
# ?: DIC Entertainment
# ✅
# ================================================================================
# Question 91/100
# Q: What rive joins the Rhine in Duisburg?
# A: Ruhr
# ?: The Emscher
# ❌
# ================================================================================
# Question 92/100
# Q: Which animal's venom did Pierre-Louis Moreau de Maupertuis work with?
# A: scorpion
# ?: Scorpion
# ✅
# ================================================================================
# Question 93/100
# Q: In the capabilities approach, grow and income are considered a means to an end rather than what?
# A: the end itself
# ?: The end is well-being
# ❌
# ================================================================================
# Question 94/100
# Q: Where are Jersey and Guernsey
# A: Channel Islands
# ?: Jersey and Guernsey are two islands in the English Channel, off the coast of France. Jersey is the larger of the two, and is the only island in the Channel Islands. Guernsey is the smaller of the two, and is the only island in the Channel Islands that is not part of the United Kingdom
# ❌
# ================================================================================
# Question 95/100
# Q: What was the boat called?
# A: teleautomaton
# ?: The "Teleautomaton."
# ❌
# ================================================================================
# Question 96/100
# Q: What did the SNP publicly opine about the oil revenues?
# A: not benefitting Scotland as much as they should
# ?: The SNP argued that the revenues from the oil were not benefitting Scotland as much as they should. The combined effect of these events led to Prime Minister Wilson committing his government to some form of devolved legislature in 1974. However, it was not until 1978 that final legislative proposals for a Scottish Assembly were passed by the United Kingdom Parliament
# ❌
# ================================================================================
# Question 97/100
# Q: How many days after Gagarin's flight did the US House Committee on Science and Astronautics meet?
# A: one day
# ?: The House Committee on Science and Astronautics met on April 13, 1961
# ❌
# ================================================================================
# Question 98/100
# Q: How can function problems typically be restated?
# A: decision problems
# ?: The most common way is to replace the function with a set of triples. For example, the multiplication of two integers can be expressed as the set of triples (a, b, c) such that the relation a × b = c holds
# ❌
# ================================================================================
# Question 99/100
# Q: What does Fortiter Defendit Triumphans mean?
# A: Triumphing by a brave defence
# ?: It means that the Scots were victorious in the siege of Newcastle
# ❌
# ================================================================================
# Question 100/100
# Q: Recent studies believe  that ctenophores are the sister lineage to what?
# A: all other animals
# ?: Ctenophores are the sister lineage to all other animals
# ❌
# ================================================================================
# Writing evalMamba2_8b.json
# Accuracy: 19.0% -- 19 correct and 81 incorrect
# Number of tokens generated: 49850 -- Time: 205.41108751296997 -- Tokens-Per-Sec: 242.6840761302741

# %%
eval(data[:100], model2_8b, tokenizer2_8b, "evalMamba2_8b_Few_shot.json", few_shot=True, batch_size=8)
# Out:
# Question 1/100
# Q: How many yards did the Panthers get for the division championshipt game?
# A: 487
# ?: 31
# ❌
# ================================================================================
# Question 2/100
# Q: What caused Jacksonville's tourism to become less desirable at the latter half of the 19th century?
# A: yellow fever outbreaks
# ?: Yellow fever outbreaks
# ✅
# ================================================================================
# Question 3/100
# Q: What are pharmacists in the United Kingdom being increasingly paid for?
# A: medicine use reviews
# ?: medication reviews
# ❌
# ================================================================================
# Question 4/100
# Q: Geoglyphs dating to what period were found in deforested land along the Amazon River?
# A: AD 0–1250
# ?: 1540s
# ❌
# ================================================================================
# Question 5/100
# Q: Who does a gender pay gap tend to favor?
# A: males in the labor market
# ?: women
# ❌
# ================================================================================
# Question 6/100
# Q: What is the annual construction industry revenue in 2014?
# A: $960 billion
# ?: $960 billion
# ✅
# ================================================================================
# Question 7/100
# Q: Which sculpture by Michelangelo has a full-size replica in the Cast Courts?
# A: David
# ?: David
# ✅
# ================================================================================
# Question 8/100
# Q: Richard Allen and Absalom Jones were licensed by St. George's Church in what year?
# A: 1784
# ?: 1784
# ✅
# ================================================================================
# Question 9/100
# Q: Where does the Rhine end?
# A: Hoek van Holland
# ?: at Hoek van Holland
# ❌
# ================================================================================
# Question 10/100
# Q: The V&A has the world's most comprehensive collection of sculptures from which period?
# A: post-classical European
# ?: Medieval
# ❌
# ================================================================================
# Question 11/100
# Q: Which country rationed gasoline and heating gas?
# A: Sweden
# ?: Sweden
# ✅
# ================================================================================
# Question 12/100
# Q: The United States is divided into how many jurisdictions?
# A: five
# ?: 5
# ❌
# ================================================================================
# Question 13/100
# Q: What is an example of a machine model that deviates from a generally accepted multi-tape Turing machine?
# A: random access machines
# ?: The Turing machine is a model of computation that is widely used in theoretical computer science. It is a deterministic, one-tape, finite-state machine that can be used to model a wide variety of computational problems. The Turing machine is a model of computation that is widely used in theoretical computer science. It is a deterministic, one-tape, finite-state machine that can be used to model a wide variety of computational problems
# ❌
# ================================================================================
# Question 14/100
# Q: What company developed the most successful steam engine indicator?
# A: Charles Porter
# ?: Charles Porter
# ✅
# ================================================================================
# Question 15/100
# Q: Who dates rocks, precisely, within the stratigraphic section?
# A: Geochronologists
# ?: biostratigraphers
# ❌
# ================================================================================
# Question 16/100
# Q: Who formulated the idea of clonal selection theory of immunity?
# A: Frank Burnet
# ?: Frank Burnet
# ✅
# ================================================================================
# Question 17/100
# Q: What is the second most abundant element?
# A: helium
# ?: Oxygen
# ❌
# ================================================================================
# Question 18/100
# Q: what was invented in 1880 that revolutionized warfare?
# A: the machine gun
# ?: machine gun
# ❌
# ================================================================================
# Question 19/100
# Q: When did Watt finish the development of his improvements to Newcomen's engine?
# A: 1775
# ?: 1763
# ❌
# ================================================================================
# Question 20/100
# Q: What is the largest item from Italy that is part of the sculpture collection?
# A: Chancel Chapel
# ?: Narcissus Restored by Valerio Cioli c1564
# ❌
# ================================================================================
# Writing evalMamba2_8b_Few_shot.json
# Question 21/100
# Q: Antibodies are transferred to the gut of the infant through what means?
# A: Breast milk or colostrum
# ?: breast milk
# ❌
# ================================================================================
# Question 22/100
# Q: Which century was there a program to straighten the Rhine?
# A: 19th Century
# ?: 19th century
# ✅
# ================================================================================
# Question 23/100
# Q: Where was the first horse racetrack located?
# A: Pole Mokotowskie
# ?: Praga
# ❌
# ================================================================================
# Question 24/100
# Q: What did the Islamic State proclaim itself in 2014?
# A: a caliphate
# ?: Islamic State
# ❌
# ================================================================================
# Question 25/100
# Q: What plants don't need light to make chloroplasts?
# A: Gymnosperms
# ?: angiosperms
# ❌
# ================================================================================
# Question 26/100
# Q: Where was Dyrrachium located?
# A: the Adriatic
# ?: Albania
# ❌
# ================================================================================
# Question 27/100
# Q: What is the expression used to denote a worst case complexity as expressed by time taken?
# A: O(n2)
# ?: O(n2)
# ✅
# ================================================================================
# Question 28/100
# Q: How would the capabilities approach achieve it's goal?
# A: through increasing functionings
# ?: by increasing functionings and capabilities
# ❌
# ================================================================================
# Question 29/100
# Q: Within what variable is L constrained according to the space hierarchy theorem?
# A: PSPACE
# ?: PSPACE
# ✅
# ================================================================================
# Question 30/100
# Q: What are the "Big Five" animals in Kenya?
# A: lion, leopard, buffalo, rhinoceros, and elephant
# ?: lion, leopard, buffalo, rhinoceros, and elephant
# ✅
# ================================================================================
# Question 31/100
# Q: What is another way of referring to stators?
# A: static discs
# ?: rotors
# ❌
# ================================================================================
# Question 32/100
# Q: When was the new two-year affiliate agreement approved?
# A: 2002
# ?: 2002
# ✅
# ================================================================================
# Question 33/100
# Q: What type of materials inside the cabin were removed to help prevent more fire hazards in the future?
# A: flammable cabin and space suit materials
# ?: oxygen, nitrogen, and carbon dioxide
# ❌
# ================================================================================
# Question 34/100
# Q: How many nations contain "Amazonas" in their names?
# A: States or departments in four nations contain "Amazonas" in their names.
# ?: 4
# ❌
# ================================================================================
# Question 35/100
# Q: What was Tesla's position with Westinghouse?
# A: consultant
# ?: Consultant
# ✅
# ================================================================================
# Question 36/100
# Q: What year were the first Doctor Who stories available on CD?
# A: 1999
# ?: 1999
# ✅
# ================================================================================
# Question 37/100
# Q: What is the term for a task that generally lends itself to being solved by a computer?
# A: computational problems
# ?: computational complexity
# ❌
# ================================================================================
# Question 38/100
# Q: What was happening to subscriber numbers in other areas of europe?
# A: flattened
# ?: The number of subscribers to pay-TV services in Europe had been declining since the mid-1990s, with the exception of the UK, where the number of subscribers had been growing
# ❌
# ================================================================================
# Question 39/100
# Q: Dutch architect Janjaap Ruijssenaars's performative architecture 3D-printed building is scheduled to be built when?
# A: Working versions of 3D-printing building technology are already printing
# ?: 2014
# ❌
# ================================================================================
# Question 40/100
# Q: When was the most recent Super Bowl hosted in the South Florida/Miami area?
# A: 2010
# ?: Super Bowl XIX
# ❌
# ================================================================================
# Writing evalMamba2_8b_Few_shot.json
# Question 41/100
# Q: The atomic number of the periodic table for oxygen?
# A: 8
# ?: 8
# ✅
# ================================================================================
# Question 42/100
# Q: How were enemy prisoners used tactically by Mongol armies?
# A: driving them in front of the army
# ?: feigned retreat
# ❌
# ================================================================================
# Question 43/100
# Q: What is the CJEU's duty?
# A: ensure that in the interpretation and application of the Treaties the law is observed
# ?: to interpret the treaties
# ❌
# ================================================================================
# Question 44/100
# Q: Who was an important figure in the twentieth-century Islamic revival in India?
# A: Sayyid Abul Ala Maududi
# ?: Sayyid Abul Ala Maududi
# ✅
# ================================================================================
# Question 45/100
# Q: When did the ban on cigarette advertising take effect for television networks?
# A: January 2, 1971
# ?: January 2, 1971
# ✅
# ================================================================================
# Question 46/100
# Q: In what form is oxygen transported in smaller containers?
# A: compressed gas
# ?: liquid oxygen
# ❌
# ================================================================================
# Question 47/100
# Q: When rich countries trade with poor countries, whose wages increase?
# A: workers in the poor countries
# ?: low-skilled workers in the rich countries
# ❌
# ================================================================================
# Question 48/100
# Q: Who led the Science and Environmental Policy Project?
# A: Fred Singer
# ?: Fred Singer
# ✅
# ================================================================================
# Question 49/100
# Q: In what year did the NFL switch to a 16-game regular season?
# A: 1978
# ?: 2011
# ❌
# ================================================================================
# Question 50/100
# Q: What does computational complexity theory most specifically seek to answer?
# A: computational problems
# ?: What is the computational complexity of a particular problem?
# ❌
# ================================================================================
# Question 51/100
# Q: What was the final score of Super Bowl 50?
# A: 24–10
# ?: Broncos 24, Panthers 10
# ❌
# ================================================================================
# Question 52/100
# Q: What did Luther call the mass instead of sacrifice?
# A: a gift
# ?: sacrifice
# ❌
# ================================================================================
# Question 53/100
# Q: What did Queen Elizabeth II open in Newcastle in 1981?
# A: A bridge
# ?: Tyne and Wear Metro
# ❌
# ================================================================================
# Question 54/100
# Q: What kind of disorders are the result of an overactive immune response?
# A: autoimmune disorders
# ?: autoimmune disorders
# ✅
# ================================================================================
# Question 55/100
# Q: Where hotel did the Panthers stay at?
# A: San Jose Marriott.
# ?: San Jose State
# ❌
# ================================================================================
# Question 56/100
# Q: Why did Westinghouse not secure a patent for a similar motor?
# A: decided Tesla's patent would probably control the market
# ?: Westinghouse was not interested in patenting the motor, but rather in securing a monopoly on the alternating current system
# ❌
# ================================================================================
# Question 57/100
# Q: What words to they think are linked to the work Kenya?
# A: Kirinyaga, Kirenyaa and Kiinyaa
# ?: Kirinyaga, Kirenyaa and Kiinyaa
# ✅
# ================================================================================
# Question 58/100
# Q: When was the first known historical reference to immunity?
# A: Athens in 430 BC
# ?: 10th century
# ❌
# ================================================================================
# Question 59/100
# Q: What was the name of the Mongol Empire's legal code?
# A: Yassa
# ?: Yassa
# ✅
# ================================================================================
# Question 60/100
# Q: When had the Six Ministries existed?
# A: since the Sui and Tang dynasties
# ?: Yuan
# ❌
# ================================================================================
# Writing evalMamba2_8b_Few_shot.json
# Question 61/100
# Q: How to Baptized Members become Professing Members?
# A: confirmation and sometimes the profession of faith
# ?: Baptized Members become Professing Members through confirmation and sometimes the profession of faith. Individuals may also become a Professing Member through transfer from another Christian denomination
# ❌
# ================================================================================
# Question 62/100
# Q: After asking if the books were his, what else did Eck ask Luther?
# A: stood by their contents
# ?: He asked him to stand by their contents
# ❌
# ================================================================================
# Question 63/100
# Q: When did the Pope warned Luther of excommunication?
# A: 15 June 1520
# ?: 1520
# ❌
# ================================================================================
# Question 64/100
# Q: When large groups of people all boycott a system or don't pay taxes it can be considered?
# A: coercive
# ?: civil disobedience
# ❌
# ================================================================================
# Question 65/100
# Q: What ABC action series went up against NBC's variety shows in Fall 1957?
# A: Zorro
# ?: The Dick Powell Show
# ❌
# ================================================================================
# Question 66/100
# Q: What was the significance of victory at Forth Niagara for British?
# A: cut off the French frontier forts further to the west and south
# ?: it was the first time the British had captured a French fort in the Americas
# ❌
# ================================================================================
# Question 67/100
# Q: What is the Latin name for Black Death?
# A: atra mors
# ?: atra mors
# ✅
# ================================================================================
# Question 68/100
# Q: What are the phagocytes that are located in tissues in contact with the external environment called?
# A: Dendritic cells
# ?: dendritic cells
# ✅
# ================================================================================
# Question 69/100
# Q: What profession was Nathan Alterman?
# A: poet
# ?: poet
# ✅
# ================================================================================
# Question 70/100
# Q: What type of vote must the Parliament have to either block or suggest changes to the Commission's proposals?
# A: a majority
# ?: ordinary legislative procedure
# ❌
# ================================================================================
# Question 71/100
# Q: What percentage of money raised was earmarked for causes in the San Francisco area?
# A: 25 percent
# ?: 25%
# ❌
# ================================================================================
# Question 72/100
# Q: In which year was the Musical Instruments gallery closed?
# A: 2010
# ?: 2010
# ✅
# ================================================================================
# Question 73/100
# Q: What scientific field's theory has received contributions from the steam engine?
# A: thermodynamic
# ?: thermodynamic
# ✅
# ================================================================================
# Question 74/100
# Q: What type of organization would need large quantities of pure oxygen?
# A: hospitals
# ?: hospital
# ❌
# ================================================================================
# Question 75/100
# Q: How much Saharan dust falls over the Amazon basin each year?
# A: 27.7 million tons
# ?: 182 million tons
# ❌
# ================================================================================
# Question 76/100
# Q: How long after a banquet with Tugh Temur did Kusala die?
# A: four days
# ?: three days
# ❌
# ================================================================================
# Question 77/100
# Q: What type of people were being brought back to the way of truth?
# A: misguided
# ?: Lutherans
# ❌
# ================================================================================
# Question 78/100
# Q: What did the Greek root pharmakos imply?
# A: sorcery or even poison
# ?: poison
# ❌
# ================================================================================
# Question 79/100
# Q: What was Fort Caroline renamed to after the Spanish attack?
# A: San Mateo
# ?: St. Augustine
# ❌
# ================================================================================
# Question 80/100
# Q: Which territory did Jochi try to protect that may have led to a dispute with his brothers?
# A: Urgench
# ?: Urgench
# ✅
# ================================================================================
# Writing evalMamba2_8b_Few_shot.json
# Question 81/100
# Q: What ranking does the Super Bowl 50 halftime show have on the list of most watched TV broadcasts?
# A: third
# ?: 3rd
# ❌
# ================================================================================
# Question 82/100
# Q: What music did the fourth soundtrack feature?
# A: music from the 2008–2010 specials
# ?: The Christmas Carol
# ❌
# ================================================================================
# Question 83/100
# Q: What administration did Ludwig Mies van der Rohe designa buiding?
# A: School of Social Service Administration
# ?: Midway
# ❌
# ================================================================================
# Question 84/100
# Q: What was Manning's passer rating for the 2015 season?
# A: 67.9
# ?: 86.4
# ❌
# ================================================================================
# Question 85/100
# Q: Issues dealt with at Westminster are not ones who is able to deal with?
# A: Scottish Parliament
# ?: reserved matters
# ❌
# ================================================================================
# Question 86/100
# Q: What was the wedding date?
# A: 12 May 1191
# ?: May 12, 1191
# ❌
# ================================================================================
# Question 87/100
# Q: What did the development of this fertile soil provide in hostile environment?
# A: agriculture and silviculture
# ?: food
# ❌
# ================================================================================
# Question 88/100
# Q: Who did the North declare for during the English civil war?
# A: the King
# ?: Charles I
# ❌
# ================================================================================
# Question 89/100
# Q: Which country does the Rhine encounter it's main tributaries?
# A: Germany
# ?: Luxembourg
# ❌
# ================================================================================
# Question 90/100
# Q: What French animation studio did ABC purchase in 1993?
# A: DIC Entertainment
# ?: DIC Entertainment
# ✅
# ================================================================================
# Question 91/100
# Q: What rive joins the Rhine in Duisburg?
# A: Ruhr
# ?: The Ruhr
# ❌
# ================================================================================
# Question 92/100
# Q: Which animal's venom did Pierre-Louis Moreau de Maupertuis work with?
# A: scorpion
# ?: scorpion
# ✅
# ================================================================================
# Question 93/100
# Q: In the capabilities approach, grow and income are considered a means to an end rather than what?
# A: the end itself
# ?: a means to an end
# ❌
# ================================================================================
# Question 94/100
# Q: Where are Jersey and Guernsey
# A: Channel Islands
# ?: Channel Islands
# ✅
# ================================================================================
# Question 95/100
# Q: What was the boat called?
# A: teleautomaton
# ?: Teleautomatics
# ❌
# ================================================================================
# Question 96/100
# Q: What did the SNP publicly opine about the oil revenues?
# A: not benefitting Scotland as much as they should
# ?: It's Scotland's oil
# ❌
# ================================================================================
# Question 97/100
# Q: How many days after Gagarin's flight did the US House Committee on Science and Astronautics meet?
# A: one day
# ?: one day
# ✅
# ================================================================================
# Question 98/100
# Q: How can function problems typically be restated?
# A: decision problems
# ?: Decision problems
# ✅
# ================================================================================
# Question 99/100
# Q: What does Fortiter Defendit Triumphans mean?
# A: Triumphing by a brave defence
# ?: Triumphing by a brave defence
# ✅
# ================================================================================
# Question 100/100
# Q: Recent studies believe  that ctenophores are the sister lineage to what?
# A: all other animals
# ?: Cnidaria
# ❌
# ================================================================================
# Writing evalMamba2_8b_Few_shot.json
# Accuracy: 33.0% -- 33 correct and 67 incorrect
# Number of tokens generated: 55698 -- Time: 274.9178593158722 -- Tokens-Per-Sec: 202.59869671109547

# %%
tokenizer2_8b = None
model2_8b = None

gc.collect()
# Out:
# 93
